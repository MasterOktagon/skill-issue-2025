# %%
#import cv2
import os

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from pathlib import Path
from PIL import Image, ImageDraw
from tensorflow.keras import backend as K
import keras
#from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Add, Conv2D, SeparableConv2D
from tensorflow.keras.layers import BatchNormalization, AveragePooling2D
from tensorflow.keras.layers import LeakyReLU, MaxPooling2D, Flatten
from tensorflow.keras.models import Model

keras.saving.get_custom_objects().clear()

# %%
IMG_HEIGHT = 264
IMG_WIDTH = 640
X_FACTOR = 1
Y_FACTOR = 1
BATCH_SIZE = 128
EPOCHS = 30    # maybe mehr?
learning_rate = 0.004    # 0.003
train_dataset_path = './images/train/'
test_dataset_path = './images/test/'

# %%
# Function to read images names and store them in a DataFrame
def grabPaths(filepath):
    labels = [str(filepath[i]).split("/")[-1] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='path').astype(str)
    
    # Concatenate filepaths and labels

    # Shuffle the DataFrame and reset index
    df = pd.DataFrame(filepath)
    
    return df

# Function to scale boxes coordinates (bacuase images are resized)
def resize_boxes(boxes):
    boxes = np.array(boxes).astype(np.float32)
    boxes = boxes * X_FACTOR
    return (np.rint(boxes)).astype(int)


# Function to draw bounding box given an image & coordinates
def plot_bbox(image, yt_box, yp_box=None, norm=False):
    # If image is normalized (/255.) reconstruct (inverse) the operation
    if norm:
        image = image * 255.
        image = image.astype("uint8")
    
    # Convert image to array if not converted
    try:
        pil_img = Image.fromarray(image)
    except:
        pil_img = Image.fromarray(image.astype('uint8'))
        
    draw_img = ImageDraw.Draw(pil_img)
    
    x1, y1, w = yt_box
    h = w
    x2, y2 = x1+w, y1+h
    draw_img.rectangle((x1, y1, x2, y2), outline='green')
    
    # If y_pred box is given, draw it
    if yp_box is not None:
        x1, y1, w = yp_box
        h = w
        x2, y2 = x1+w, y1+h
        draw_img.rectangle((x1, y1, x2, y2), outline='red')
    return pil_img


# Function to build convolutionl block
def convblock(previous_layer, n_filters, filter_windows=(3,3,3), padding='same', pool=None):
    # [DepthwiseConv -> BatchNorm -> LeakyReLU] x3 + Residual connection -> Pooling (optional)

    x = SeparableConv2D(n_filters[0], filter_windows[0], padding=padding)(previous_layer)
    x_short = x
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[1], filter_windows[1], padding=padding)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[2], filter_windows[2], padding=padding)(x)
    x = BatchNormalization()(x)
    x = Add()([x, x_short])
    x = LeakyReLU()(x)
    
    if pool == 'max':
        x = MaxPooling2D(pool_size=(2,2))(x)
    elif pool == 'avg':
        x = AveragePooling2D(pool_size=(2,2))(x)
    
    return x

# Function to show samples
def visualize_samples(datagen, row_col_len=4, figsize=None):
    figsize = figsize or np.array((row_col_len, row_col_len)) * 4
    fig, ax = plt.subplots(row_col_len*5, row_col_len, figsize=figsize)
    for i in range(row_col_len*5):
        for j in range(row_col_len):
            batch_index = np.random.randint(0, BATCH_SIZE/2)
            output_classes = np.array(datagen[batch_index][1]['class_out'])
            classes_true = np.where(output_classes == 1)[0]
            sample_index = classes_true[np.random.randint(0, classes_true.shape[0])]
            image = datagen[batch_index][0][sample_index]
            print(image.shape)
            box = datagen[batch_index][1]['box_out'][sample_index]
            plotted_box = plot_bbox(image, box, norm=True)
            ax[i,j].imshow(plotted_box)
            ax[i,j].set_axis_off()
            #ax[i,j].title.set_text(str(batch_index*BATCH_SIZE+sample_index))
    plt.show()
    


# Function to make a prediction during training
def visualize_prediction(model, data):    
    # Select a sample where an object exists
    output_classes = np.array(custom_test_gen[0][1]['class_out'])
    sample_index = np.where(output_classes == 1)[0]
    sample_index = sample_index[0] if sample_index[0] else 0 
    
    # Get image
    image = np.array([data[0][0][sample_index]])
    
    # Set y_true & y_pred for class & bounding box
    yt_box = np.array([custom_test_gen[0][1]['box_out'][sample_index]])
    yt_class = np.array([custom_test_gen[0][1]['class_out'][sample_index]])
    yp_class, yp_box = model.predict(image)

    # Plot bounding box on image & show it
    image_plotted = plot_bbox(image[0], yt_box[0], yp_box[0], norm=True) 
    plt.imshow(image_plotted)
    plt.axis('off')
    
    # Print y_true class & y_pred class
    print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
    plt.show()


# Function to reduce learning rate during training        
def lr_scheduler(epoch, lr):
    if epoch > 10:
        lr = lr * tf.math.exp(-0.1) #-0.15
        print(lr)
    return float(lr)

# Function to calculate MSE Loss function
# for samples where object exists
@keras.saving.register_keras_serializable()
def custom_mse(y_true, y_pred):
    mask = K.not_equal(K.sum(y_true, axis=1), 0.0)
    y_true_custom = y_true[mask]
    y_pred_custom = y_pred[mask]
    mse = tf.keras.losses.MeanSquaredError()
    result = mse(y_true_custom, y_pred_custom) # * 0.3
    return result

# %%
# Read CSV
train_dataset = pd.read_csv('./images/train/dataset.csv')
train_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']
test_dataset = pd.read_csv('./images/test/dataset.csv')
test_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']


# List directories of files
train_image_dir_hand = Path('./images/train')
train_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))
test_image_dir_hand = Path('./images/test')
test_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))

# Create dataframe of {paths, labels}
train_df_hand = grabPaths(train_filepaths_hand)
test_df_hand = grabPaths(test_filepaths_hand)

train_dataset['path'] = "./images/train/" + train_dataset['path']
test_dataset['path'] = "./images/test/" + test_dataset['path']


# Resize boxes, keep zeros if no object exists
train_dataset.iloc[:,2:] = resize_boxes(train_dataset.iloc[:,2:])
test_dataset.iloc[:,2:] = resize_boxes(test_dataset.iloc[:,2:])

# %%
ax = sns.countplot(x='ball_exists', data=train_dataset)
ax.set(xlabel='Object exists in image', ylabel='No. of Image')
# Out:
# [Text(0.5, 0, 'Object exists in image'), Text(0, 0.5, 'No. of Image')]

# %%
# balance dataset (undersampling)
# balls = dataset[dataset['ball_exists'] == 1]
# noballs = dataset[dataset['ball_exists'] == 0]
# balls = balls.sample(frac=0.75).reset_index(drop=True)

# # merge balanced classes & shuffle
# train_df = pd.concat((balls, noballs)).sample(frac=1.).reset_index(drop=True)

# train_df, test_df = train_test_split(train_df, test_size=0.2)

# print(f"No. Training Samples: {train_df.shape[0]}\nNo. Validation Samples: {test_df.shape[0]}")

# %%
# Create custom Generator for multiple output models
class MultiOutputGen(tf.keras.utils.Sequence):
    def __init__(self, input_gen, output_gen):
        self.inpgen = input_gen
        self.outgen = output_gen
#         assert len(input_gen) == len(output_gen)

    def __len__(self):
        return len(self.inpgen)

    def __getitem__(self, i):
        images = self.inpgen[i]
        start = i * images.shape[0]
        end = (i+1) * images.shape[0]
        classes_num = self.outgen.iloc[start:end,0].values
        x = self.outgen.iloc[start:end,1]
        y = self.outgen.iloc[start:end,2]
        w = self.outgen.iloc[start:end,3]
#         h = self.outgen.iloc[start:end,4]
        return images, {'class_out':classes_num, 'box_out':np.array([x, y, w]).T}

    def on_epoch_end(self):
        self.inpgen.on_epoch_end()
    
# Class to visualize predictions during training
class ConvergenceVisualization(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        global custom_test_gen
        visualize_prediction(self.model, custom_test_gen)

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    brightness_range=(0.8, 1.2),
    rescale = 1./255.,
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255.,
)

train_images = train_generator.flow_from_dataframe(
    dataframe=train_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

# Create multi-output generator
custom_train_gen = MultiOutputGen(train_images, train_dataset.iloc[:,1:])
custom_test_gen = MultiOutputGen(test_images, test_dataset.iloc[:,1:])
# Out:
# Found 8458 validated image filenames.
# Found 637 validated image filenames.

# %%
visualize_samples(custom_train_gen, 2)
# Out:
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)
# (264, 640, 3)

# %%
# BEST MODEL

inp = Input(shape=(IMG_HEIGHT,IMG_WIDTH,3), name='image')

X = SeparableConv2D(64, (7,7), strides=2, padding='valid')(inp)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = SeparableConv2D(192, (3,3), strides=1, padding='same')(X)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = convblock(X, [16, 16, 16], pool='max')
X = convblock(X, [32, 32, 32], pool='max')
X = convblock(X, [64, 64, 64], pool='max')
X = convblock(X, [128, 128, 128], pool='max')
X = convblock(X, [256, 256, 256])

X = Flatten()(X)
boxX = Dense(512)(X)
boxX = LeakyReLU()(boxX)

classX = Dense(128)(X)
classX = LeakyReLU()(classX)

box_out = Dense(3, name='box_out')(boxX)
class_out = Dense(1, name='class_out', activation='sigmoid')(classX)


model = Model(inp, [class_out, box_out])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 264, 640, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d              │ (None, 129, 317, 64)      │             403 │ image[0][0]                │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 158, 64)       │               0 │ separable_conv2d[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_1            │ (None, 64, 158, 192)      │          13,056 │ max_pooling2d[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 79, 192)       │               0 │ separable_conv2d_1[0][0]   │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_2            │ (None, 32, 79, 16)        │           4,816 │ max_pooling2d_1[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 32, 79, 16)        │              64 │ separable_conv2d_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 32, 79, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_3            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu[0][0]          │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_4            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu_1[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 79, 16)        │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ separable_conv2d_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 39, 16)        │               0 │ leaky_re_lu_2[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_5            │ (None, 16, 39, 32)        │             688 │ max_pooling2d_2[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_6            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_3[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_7            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_4[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 16, 39, 32)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ separable_conv2d_5[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 8, 19, 32)         │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_8            │ (None, 8, 19, 64)         │           2,400 │ max_pooling2d_3[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_8[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_9            │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_6[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_9[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_10           │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_7[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_10[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 8, 19, 64)         │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ separable_conv2d_8[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 4, 9, 64)          │               0 │ leaky_re_lu_8[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_11           │ (None, 4, 9, 128)         │           8,896 │ max_pooling2d_4[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 4, 9, 128)         │             512 │ separable_conv2d_11[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 4, 9, 128)         │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_12           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_9[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_12[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_13           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_10[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_13[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 4, 9, 128)         │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ separable_conv2d_11[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 2, 4, 128)         │               0 │ leaky_re_lu_11[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_14           │ (None, 2, 4, 256)         │          34,176 │ max_pooling2d_5[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_14[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_12 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_15           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_12[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_15[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_13 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_16           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_13[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_16[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 2, 4, 256)         │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ separable_conv2d_14[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_14 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2048)              │               0 │ leaky_re_lu_14[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │         262,272 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 512)               │       1,049,088 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_16 (LeakyReLU)    │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_15 (LeakyReLU)    │ (None, 512)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_out (Dense)             │ (None, 1)                 │             129 │ leaky_re_lu_16[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ box_out (Dense)               │ (None, 3)                 │           1,539 │ leaky_re_lu_15[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,567,927 (5.98 MB)
#  Trainable params: 1,564,951 (5.97 MB)
#  Non-trainable params: 2,976 (11.62 KB)

# %%
adam = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model.compile(
    loss={
        "box_out":custom_mse,
        'class_out':'binary_crossentropy'
    },
    metrics={
        'class_out':'accuracy'
    },
    optimizer=adam
)

# %%
history = model.fit(
    custom_train_gen,
    epochs=EPOCHS,
    validation_data=custom_test_gen,
    callbacks=[
        tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
        ConvergenceVisualization()
    ]
)
# Out:
# C:\Users\Salkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step- box_out_loss: 12603.2295 - class_out_accuracy: 0.8913 - class_out_loss: 4.5101 - loss: 12556.2764
# Class: y_true= [1]  | y_pred= 1
# C:\Users\Salkin\AppData\Local\Temp\ipykernel_28236\2401895158.py:118: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - box_out_loss: 12544.3389 - class_out_accuracy: 0.8915 - class_out_loss: 4.5278 - loss: 12497.0078 - val_box_out_loss: 14874.6191 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.5161 - val_loss: 14946.1865 - learning_rate: 0.0040
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 5928.4673 - class_out_accuracy: 0.8440 - class_out_loss: 1.2934 - loss: 5791.5723
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - box_out_loss: 5931.5317 - class_out_accuracy: 0.8450 - class_out_loss: 1.2846 - loss: 5794.3188 - val_box_out_loss: 12031.4883 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 2.5551 - val_loss: 12090.6992 - learning_rate: 0.0040
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 5610.1172 - class_out_accuracy: 0.9084 - class_out_loss: 0.8515 - loss: 5496.7598
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 66s 985ms/step - box_out_loss: 5607.1294 - class_out_accuracy: 0.9084 - class_out_loss: 0.8553 - loss: 5493.6968 - val_box_out_loss: 10094.9639 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 0.8589 - val_loss: 10143.3643 - learning_rate: 0.0040
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 4604.4033 - class_out_accuracy: 0.9484 - class_out_loss: 0.4085 - loss: 4398.7334
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 66s 977ms/step - box_out_loss: 4600.7905 - class_out_accuracy: 0.9483 - class_out_loss: 0.4095 - loss: 4396.4004 - val_box_out_loss: 7825.4595 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.9437 - val_loss: 7864.2520 - learning_rate: 0.0040
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 3765.7849 - class_out_accuracy: 0.9487 - class_out_loss: 0.3886 - loss: 3693.5566
# Class: y_true= [1]  | y_pred= 0
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 66s 985ms/step - box_out_loss: 3774.7568 - class_out_accuracy: 0.9487 - class_out_loss: 0.3891 - loss: 3699.6956 - val_box_out_loss: 10250.1973 - val_class_out_accuracy: 0.6358 - val_class_out_loss: 1.4429 - val_loss: 10299.9219 - learning_rate: 0.0040
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 5290.3022 - class_out_accuracy: 0.9467 - class_out_loss: 0.2476 - loss: 5190.4370
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 66s 982ms/step - box_out_loss: 5280.7100 - class_out_accuracy: 0.9465 - class_out_loss: 0.2475 - loss: 5180.4199 - val_box_out_loss: 2712.1719 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 8.4138 - val_loss: 2733.3364 - learning_rate: 0.0040
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 3377.8425 - class_out_accuracy: 0.9612 - class_out_loss: 0.5703 - loss: 3313.6003
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 992ms/step - box_out_loss: 3377.2998 - class_out_accuracy: 0.9610 - class_out_loss: 0.5689 - loss: 3311.9392 - val_box_out_loss: 3542.5930 - val_class_out_accuracy: 0.4207 - val_class_out_loss: 1.2816 - val_loss: 3560.5562 - learning_rate: 0.0040
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/steptep - box_out_loss: 2952.6052 - class_out_accuracy: 0.8966 - class_out_loss: 0.3691 - loss: 2498.1040
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - box_out_loss: 2949.5642 - class_out_accuracy: 0.8973 - class_out_loss: 0.3681 - loss: 2499.5254 - val_box_out_loss: 1580.7893 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 2.8913 - val_loss: 1591.1176 - learning_rate: 0.0040
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 2004.5385 - class_out_accuracy: 0.9834 - class_out_loss: 0.1021 - loss: 1984.7529
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 990ms/step - box_out_loss: 2008.0698 - class_out_accuracy: 0.9829 - class_out_loss: 0.1041 - loss: 1986.2648 - val_box_out_loss: 1786.8953 - val_class_out_accuracy: 0.4286 - val_class_out_loss: 1.0181 - val_loss: 1796.3262 - learning_rate: 0.0040
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/steptep - box_out_loss: 3370.8464 - class_out_accuracy: 0.9445 - class_out_loss: 0.2517 - loss: 2809.5205
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 66s 980ms/step - box_out_loss: 3363.1543 - class_out_accuracy: 0.9445 - class_out_loss: 0.2525 - loss: 2806.2659 - val_box_out_loss: 2021.0902 - val_class_out_accuracy: 0.4349 - val_class_out_loss: 1.1416 - val_loss: 2031.7478 - learning_rate: 0.0040
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 2008.9027 - class_out_accuracy: 0.9441 - class_out_loss: 0.2484 - loss: 1806.4122
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - box_out_loss: 2009.2153 - class_out_accuracy: 0.9443 - class_out_loss: 0.2483 - loss: 1807.1045 - val_box_out_loss: 2122.2180 - val_class_out_accuracy: 0.4474 - val_class_out_loss: 1.1805 - val_loss: 2133.3904 - learning_rate: 0.0040
# tf.Tensor(0.0036193498, shape=(), dtype=float32)
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1511.0499 - class_out_accuracy: 0.9486 - class_out_loss: 0.1990 - loss: 1269.1484
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 992ms/step - box_out_loss: 1510.2806 - class_out_accuracy: 0.9487 - class_out_loss: 0.1985 - loss: 1269.5204 - val_box_out_loss: 1403.8425 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 3.3605 - val_loss: 1413.8053 - learning_rate: 0.0036
# tf.Tensor(0.0032749232, shape=(), dtype=float32)
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 1178.2164 - class_out_accuracy: 0.9743 - class_out_loss: 0.1198 - loss: 1025.4452
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - box_out_loss: 1178.3373 - class_out_accuracy: 0.9740 - class_out_loss: 0.1208 - loss: 1025.5054 - val_box_out_loss: 1489.5876 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 2.4070 - val_loss: 1499.0031 - learning_rate: 0.0033
# tf.Tensor(0.002963273, shape=(), dtype=float32)
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 923.6364 - class_out_accuracy: 0.9726 - class_out_loss: 0.1342 - loss: 869.0695
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - box_out_loss: 926.0463 - class_out_accuracy: 0.9724 - class_out_loss: 0.1351 - loss: 870.9901 - val_box_out_loss: 1245.2380 - val_class_out_accuracy: 0.4066 - val_class_out_loss: 1.3876 - val_loss: 1252.4856 - learning_rate: 0.0030
# tf.Tensor(0.0026812805, shape=(), dtype=float32)
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 999.9636 - class_out_accuracy: 0.9662 - class_out_loss: 0.1341 - loss: 902.2938
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 993ms/step - box_out_loss: 1003.3913 - class_out_accuracy: 0.9660 - class_out_loss: 0.1349 - loss: 904.3594 - val_box_out_loss: 1493.3043 - val_class_out_accuracy: 0.3768 - val_class_out_loss: 2.5222 - val_loss: 1502.8514 - learning_rate: 0.0027
# tf.Tensor(0.002426123, shape=(), dtype=float32)
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1109.8351 - class_out_accuracy: 0.9648 - class_out_loss: 0.1160 - loss: 993.6132
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - box_out_loss: 1109.1324 - class_out_accuracy: 0.9647 - class_out_loss: 0.1166 - loss: 992.0645 - val_box_out_loss: 1564.7678 - val_class_out_accuracy: 0.3752 - val_class_out_loss: 2.0478 - val_loss: 1574.1799 - learning_rate: 0.0024
# tf.Tensor(0.002195247, shape=(), dtype=float32)
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 676.5300 - class_out_accuracy: 0.9704 - class_out_loss: 0.1136 - loss: 589.5212
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 66s 980ms/step - box_out_loss: 677.6280 - class_out_accuracy: 0.9702 - class_out_loss: 0.1142 - loss: 589.3927 - val_box_out_loss: 1367.7493 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 3.0463 - val_loss: 1377.2286 - learning_rate: 0.0022
# tf.Tensor(0.0019863416, shape=(), dtype=float32)
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/steptep - box_out_loss: 452.1600 - class_out_accuracy: 0.9483 - class_out_loss: 0.2227 - loss: 443.1371
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - box_out_loss: 454.6800 - class_out_accuracy: 0.9484 - class_out_loss: 0.2221 - loss: 443.5676 - val_box_out_loss: 1323.9764 - val_class_out_accuracy: 0.3956 - val_class_out_loss: 1.6451 - val_loss: 1331.8523 - learning_rate: 0.0020
# tf.Tensor(0.0017973161, shape=(), dtype=float32)
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 440.8845 - class_out_accuracy: 0.9276 - class_out_loss: 0.2078 - loss: 414.2479
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - box_out_loss: 442.5676 - class_out_accuracy: 0.9280 - class_out_loss: 0.2071 - loss: 414.9660 - val_box_out_loss: 1254.3069 - val_class_out_accuracy: 0.4050 - val_class_out_loss: 2.1447 - val_loss: 1262.3533 - learning_rate: 0.0018
# tf.Tensor(0.0016262789, shape=(), dtype=float32)
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 520.1188 - class_out_accuracy: 0.9821 - class_out_loss: 0.0735 - loss: 461.7481
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - box_out_loss: 521.2462 - class_out_accuracy: 0.9818 - class_out_loss: 0.0747 - loss: 462.4067 - val_box_out_loss: 1299.2411 - val_class_out_accuracy: 0.4066 - val_class_out_loss: 1.8783 - val_loss: 1307.2333 - learning_rate: 0.0016
# tf.Tensor(0.001471518, shape=(), dtype=float32)
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 443.5293 - class_out_accuracy: 0.9700 - class_out_loss: 0.1085 - loss: 427.1494
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - box_out_loss: 445.2796 - class_out_accuracy: 0.9698 - class_out_loss: 0.1091 - loss: 427.4521 - val_box_out_loss: 1650.0717 - val_class_out_accuracy: 0.4458 - val_class_out_loss: 1.7347 - val_loss: 1659.5734 - learning_rate: 0.0015
# tf.Tensor(0.0013314845, shape=(), dtype=float32)
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/steptep - box_out_loss: 1021.6185 - class_out_accuracy: 0.9336 - class_out_loss: 0.2165 - loss: 751.1508
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 992ms/step - box_out_loss: 1019.7040 - class_out_accuracy: 0.9340 - class_out_loss: 0.2156 - loss: 750.9600 - val_box_out_loss: 1192.4684 - val_class_out_accuracy: 0.4631 - val_class_out_loss: 1.8740 - val_loss: 1199.9531 - learning_rate: 0.0013
# tf.Tensor(0.001204777, shape=(), dtype=float32)
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 613.8432 - class_out_accuracy: 0.9425 - class_out_loss: 0.1987 - loss: 473.5267
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - box_out_loss: 614.0131 - class_out_accuracy: 0.9427 - class_out_loss: 0.1980 - loss: 473.6386 - val_box_out_loss: 1178.7043 - val_class_out_accuracy: 0.4082 - val_class_out_loss: 1.8391 - val_loss: 1186.0900 - learning_rate: 0.0012
# tf.Tensor(0.0010901274, shape=(), dtype=float32)
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 543.7656 - class_out_accuracy: 0.9882 - class_out_loss: 0.0546 - loss: 382.2726
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 66s 986ms/step - box_out_loss: 542.6876 - class_out_accuracy: 0.9878 - class_out_loss: 0.0560 - loss: 382.0207 - val_box_out_loss: 1058.1589 - val_class_out_accuracy: 0.5290 - val_class_out_loss: 0.8762 - val_loss: 1064.0162 - learning_rate: 0.0011
# tf.Tensor(0.0009863881, shape=(), dtype=float32)
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 348.4729 - class_out_accuracy: 0.9700 - class_out_loss: 0.1560 - loss: 296.6262
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 999ms/step - box_out_loss: 348.4822 - class_out_accuracy: 0.9698 - class_out_loss: 0.1565 - loss: 296.8833 - val_box_out_loss: 1086.1970 - val_class_out_accuracy: 0.4066 - val_class_out_loss: 1.6064 - val_loss: 1092.9146 - learning_rate: 9.8639e-04
# tf.Tensor(0.0008925208, shape=(), dtype=float32)
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 268.7495 - class_out_accuracy: 0.9909 - class_out_loss: 0.0470 - loss: 267.2540
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - box_out_loss: 268.9358 - class_out_accuracy: 0.9904 - class_out_loss: 0.0484 - loss: 266.9655 - val_box_out_loss: 1080.8054 - val_class_out_accuracy: 0.4662 - val_class_out_loss: 1.1187 - val_loss: 1087.0110 - learning_rate: 8.9252e-04
# tf.Tensor(0.00080758624, shape=(), dtype=float32)
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 242.8580 - class_out_accuracy: 0.9669 - class_out_loss: 0.1241 - loss: 238.8972
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 997ms/step - box_out_loss: 242.9050 - class_out_accuracy: 0.9668 - class_out_loss: 0.1244 - loss: 238.8108 - val_box_out_loss: 1050.5475 - val_class_out_accuracy: 0.4568 - val_class_out_loss: 1.2688 - val_loss: 1056.7603 - learning_rate: 8.0759e-04
# tf.Tensor(0.00073073426, shape=(), dtype=float32)
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 229.0981 - class_out_accuracy: 0.9897 - class_out_loss: 0.0636 - loss: 217.3408
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 998ms/step - box_out_loss: 229.0738 - class_out_accuracy: 0.9892 - class_out_loss: 0.0646 - loss: 217.2196 - val_box_out_loss: 1086.5925 - val_class_out_accuracy: 0.4349 - val_class_out_loss: 1.5059 - val_loss: 1093.2118 - learning_rate: 7.3073e-04
# tf.Tensor(0.0006611957, shape=(), dtype=float32)
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 243.5280 - class_out_accuracy: 0.9324 - class_out_loss: 0.2153 - loss: 199.7445
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 66s 987ms/step - box_out_loss: 243.2734 - class_out_accuracy: 0.9327 - class_out_loss: 0.2145 - loss: 199.7332 - val_box_out_loss: 1124.8503 - val_class_out_accuracy: 0.4584 - val_class_out_loss: 1.3573 - val_loss: 1131.5012 - learning_rate: 6.6120e-04
# tf.Tensor(0.00059827464, shape=(), dtype=float32)
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 200.3269 - class_out_accuracy: 0.9251 - class_out_loss: 0.1785 - loss: 171.0808
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 67s 998ms/step - box_out_loss: 200.4079 - class_out_accuracy: 0.9256 - class_out_loss: 0.1777 - loss: 171.3273 - val_box_out_loss: 1102.9674 - val_class_out_accuracy: 0.4349 - val_class_out_loss: 1.6662 - val_loss: 1109.8232 - learning_rate: 5.9827e-04

# %%
# Accuracy & Loss Visualization

#  Overall Loss
train_overall_loss = history.history['loss']
val_overall_loss = history.history['val_loss']

# Classification Accuracy
train_classification_acc = history.history['class_out_accuracy']
val_classification_acc = history.history['val_class_out_accuracy']

# Classification Loss
train_classification_loss = history.history['class_out_loss']
val_classification_loss = history.history['val_class_out_loss']

# Bounding Box Loss
train_bbox_loss = history.history['box_out_loss']
val_bbox_loss = history.history['val_box_out_loss']

epochs = range(1, len(history.history['loss'])+1)

f, ax = plt.subplots(nrows=2,ncols=2,figsize=(18,15))
    
ax[0,0].plot(epochs, train_overall_loss,  marker='o', label='Training')
ax[0,0].plot(epochs, val_overall_loss, marker='o', color = 'green', label='Validation')
ax[0,0].set_title('Overall Loss')
ax[0,0].set_xlabel('Epochs')
ax[0,0].set_ylabel('Loss')
ax[0,0].legend(loc='best')
ax[0,0].grid(True)

ax[0,1].plot(epochs, train_bbox_loss, marker='o', label='Training')
ax[0,1].plot(epochs, val_bbox_loss, marker='o', color = 'green', label='Validation')
ax[0,1].set_title('Bounding Box Loss')
ax[0,1].set_xlabel('Epochs')
ax[0,1].set_ylabel('Loss')
ax[0,1].legend(loc='best')
ax[0,1].grid(True)



ax[1,0].plot(epochs, train_classification_acc,  marker='o', label='Training')
ax[1,0].plot(epochs, val_classification_acc, marker='o', color = 'green', label='Validation')
ax[1,0].set_title('Classification Accuracy')
ax[1,0].set_xlabel('Epochs')
ax[1,0].set_ylabel('Accuracy')
ax[1,0].legend(loc='best')
ax[1,0].grid(True)

ax[1,1].plot(epochs, train_classification_loss, marker='o', label='Training')
ax[1,1].plot(epochs, val_classification_loss, marker='o', color = 'green', label='Validation')
ax[1,1].set_title('Classification Loss')
ax[1,1].set_xlabel('Epochs')
ax[1,1].set_ylabel('Loss')
ax[1,1].legend(loc='best')
ax[1,1].grid(True)

plt.show()
f.savefig('LossAndAccuracy.eps', format='eps')
plt.close()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#model.save("test1 ball detection.h5")
model.save("ball_detection_V2.keras")

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("ball_detection.tflite", "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Salkin\AppData\Local\Temp\tmprpk5j6po\assets
# INFO:tensorflow:Assets written to: C:\Users\Salkin\AppData\Local\Temp\tmprpk5j6po\assets
# Saved artifact at 'C:\Users\Salkin\AppData\Local\Temp\tmprpk5j6po'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 264, 640, 3), dtype=tf.float32, name='image')
# Output Type:
#   List[TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)]
# Captures:
#   2151974989712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2151974986640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025170256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025169680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025171792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025170640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025170832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025172176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025171984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025170064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025169488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025172368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025171216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025173328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025174096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025174288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025176208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025174864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025176400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152025175632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031060240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031060816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031061008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031061584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031061968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031062352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031060624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031063120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031063504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031062736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031065040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031064272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031064464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031064848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031065808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031066192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031065424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031067920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031064656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031068112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031067344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031068880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031069264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031068496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031070800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031070032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031070224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031070608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031071568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031071952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031071184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031073488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031072720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031072912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031073296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031074256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031074640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031073872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031075792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031388112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031075600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031075984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031388304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031388496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031388688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031390224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031389456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031389648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031390032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031390992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031391376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031390608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031392912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031392144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031392336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031392720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031393680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031394064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031393296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031395600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031394832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031395024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031395408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031396368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031396752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031395984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031398288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031397520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031397712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031398096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031399056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031399440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031398672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031400976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031400208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031400400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031400784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031401744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031402128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031401360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031403280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031403664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031403088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031403472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031764752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031765328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031765136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031766864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031766096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031766288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031766672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031767632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031768784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031768976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031769552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031769744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031770320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031770512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2152031771280: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 6281364

# %%
new_model = tf.keras.models.load_model("ball_detection_V2.keras")
new_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 264, 640, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d              │ (None, 129, 317, 64)      │             403 │ image[0][0]                │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 158, 64)       │               0 │ separable_conv2d[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_1            │ (None, 64, 158, 192)      │          13,056 │ max_pooling2d[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 79, 192)       │               0 │ separable_conv2d_1[0][0]   │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_2            │ (None, 32, 79, 16)        │           4,816 │ max_pooling2d_1[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 32, 79, 16)        │              64 │ separable_conv2d_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 32, 79, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_3            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu[0][0]          │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_4            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu_1[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 79, 16)        │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ separable_conv2d_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 39, 16)        │               0 │ leaky_re_lu_2[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_5            │ (None, 16, 39, 32)        │             688 │ max_pooling2d_2[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_6            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_3[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_7            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_4[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 16, 39, 32)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ separable_conv2d_5[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 8, 19, 32)         │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_8            │ (None, 8, 19, 64)         │           2,400 │ max_pooling2d_3[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_8[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_9            │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_6[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_9[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_10           │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_7[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_10[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 8, 19, 64)         │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ separable_conv2d_8[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 4, 9, 64)          │               0 │ leaky_re_lu_8[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_11           │ (None, 4, 9, 128)         │           8,896 │ max_pooling2d_4[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 4, 9, 128)         │             512 │ separable_conv2d_11[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 4, 9, 128)         │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_12           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_9[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_12[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_13           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_10[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_13[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 4, 9, 128)         │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ separable_conv2d_11[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 2, 4, 128)         │               0 │ leaky_re_lu_11[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_14           │ (None, 2, 4, 256)         │          34,176 │ max_pooling2d_5[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_14[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_12 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_15           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_12[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_15[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_13 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_16           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_13[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_16[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 2, 4, 256)         │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ separable_conv2d_14[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_14 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2048)              │               0 │ leaky_re_lu_14[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │         262,272 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 512)               │       1,049,088 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_16 (LeakyReLU)    │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_15 (LeakyReLU)    │ (None, 512)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_out (Dense)             │ (None, 1)                 │             129 │ leaky_re_lu_16[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ box_out (Dense)               │ (None, 3)                 │           1,539 │ leaky_re_lu_15[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,697,831 (17.92 MB)
#  Trainable params: 1,564,951 (5.97 MB)
#  Non-trainable params: 2,976 (11.62 KB)
#  Optimizer params: 3,129,904 (11.94 MB)

# %%
valid_dataset = pd.read_csv('./images/valid/dataset.csv')
#print(valid_dataset)
def visualize_evaluation(model, name):    
    # Get image
    im = Image.open("./images/valid/"+name)
    image = np.expand_dims(np.asarray(im)/255, axis=0)
    print(image.shape)
    #print(image)
    
    # Set y_true & y_pred for class & bounding box
    print(valid_dataset.loc[valid_dataset['path']==name]['x'], valid_dataset.loc[valid_dataset['path']==name]['y'], valid_dataset.loc[valid_dataset['path']==name]['w'])
    yt_box = np.array([valid_dataset.loc[valid_dataset['path']==name]['x'], valid_dataset.loc[valid_dataset['path']==name]['y'], valid_dataset.loc[valid_dataset['path']==name]['w']])
    yt_class = np.array(valid_dataset.loc[valid_dataset['path']==name]['ball_exists'])
    
    yp_class, yp_box = model.predict(image)
    print(yp_class, yp_box)

    camera_fov = 53.50
    angle = (yp_box[0][0]+yp_box[0][2]/2)/640 *camera_fov - camera_fov/2
    print("Ball Angle", angle)

    # Plot bounding box on image & show it
    image_plotted = plot_bbox(image[0], yt_box, yp_box[0], norm=True) #True?
    plt.imshow(image_plotted)
    plt.axis('off')
    
    # Print y_true class & y_pred class
    print("Class: y_true=", yt_class, " | y_pred=", int(yp_class[0][0] >= 0.5))
    plt.show()

# %%
visualize_evaluation(new_model, "frame574.jpg")
# Out:
# (1, 264, 640, 3)
# 1284    0
# Name: x, dtype: int64 1284    0
# Name: y, dtype: int64 1284    0
# Name: w, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# [[0.9867621]] [[404.06396  46.24384 143.4262 ]]
# Ball Angle 13.021988
# Class: y_true= [0]  | y_pred= 1

# %%
def visu_tets(sample_index):
    data = custom_test_gen
    image = np.array([data[0][0][sample_index]])
    yt_box = np.array([custom_test_gen[0][1]['box_out'][sample_index]])
    yt_class = np.array([custom_test_gen[0][1]['class_out'][sample_index]])
    yp_class, yp_box = model.predict(image)
    print(image.shape)
    print(image)
    print(image[0].shape)
    image_plotted = plot_bbox(image[0], yt_box[0], yp_box[0], norm=True) 
    plt.imshow(image_plotted)
    plt.axis('off')
    plt.show()

# %%
visu_tets(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 visu_tets(0)
#
# NameError: name 'visu_tets' is not defined
