# %%
#import cv2
import os

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from pathlib import Path
from PIL import Image, ImageDraw
from tensorflow.keras import backend as K
import keras
#from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Add, Conv2D, SeparableConv2D
from tensorflow.keras.layers import BatchNormalization, AveragePooling2D
from tensorflow.keras.layers import LeakyReLU, MaxPooling2D, Flatten
from tensorflow.keras.models import Model

keras.saving.get_custom_objects().clear()

# %%
IMG_HEIGHT = 264
IMG_WIDTH = 640
X_FACTOR = 1
Y_FACTOR = 1
BATCH_SIZE = 128
EPOCHS = 30    # maybe mehr?
learning_rate = 0.0055    # 0.005
train_dataset_path = './images/train/'
test_dataset_path = './images/test/'

# %%
# Function to read images names and store them in a DataFrame
def grabPaths(filepath):
    labels = [str(filepath[i]).split("/")[-1] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='path').astype(str)
    
    # Concatenate filepaths and labels

    # Shuffle the DataFrame and reset index
    df = pd.DataFrame(filepath)
    
    return df

# Function to scale boxes coordinates (bacuase images are resized)
def resize_boxes(boxes):
    boxes = np.array(boxes).astype(np.float32)
    boxes = boxes * X_FACTOR
    return (np.rint(boxes)).astype(int)


# Function to draw bounding box given an image & coordinates
def plot_bbox(image, yt_box, yp_box=None, norm=False):
    # If image is normalized (/255.) reconstruct (inverse) the operation
    if norm:
        image = image * 255.
        image = image.astype("uint8")
    
    # Convert image to array if not converted
    try:
        pil_img = Image.fromarray(image)
    except:
        pil_img = Image.fromarray(image.astype('uint8'))
        
    draw_img = ImageDraw.Draw(pil_img)

    try:
        x1, y1, w = yt_box
        h = w
        x2, y2 = x1+w, y1+h
        draw_img.rectangle((x1, y1, x2, y2), outline='green')
    except:
        pass
    
    # If y_pred box is given, draw it
    if yp_box is not None:
        x1, y1, w = yp_box
        if w<0:
            print("how!!!!!!!!!!!!!!!!!!!!")
            w = abs(w)
        h = w
        x2, y2 = x1+w, y1+h
        draw_img.rectangle((x1, y1, x2+1, y2+1), outline='red')
    return pil_img


# Function to build convolutionl block
def convblock(previous_layer, n_filters, filter_windows=(3,3,3), padding='same', pool=None):
    # [DepthwiseConv -> BatchNorm -> LeakyReLU] x3 + Residual connection -> Pooling (optional)

    x = SeparableConv2D(n_filters[0], filter_windows[0], padding=padding)(previous_layer)
    x_short = x
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[1], filter_windows[1], padding=padding)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[2], filter_windows[2], padding=padding)(x)
    x = BatchNormalization()(x)
    x = Add()([x, x_short])
    x = LeakyReLU()(x)
    
    if pool == 'max':
        x = MaxPooling2D(pool_size=(2,2))(x)
    elif pool == 'avg':
        x = AveragePooling2D(pool_size=(2,2))(x)
    
    return x

# Function to show samples
def visualize_samples(datagen, row_col_len=4, figsize=None):
    figsize = figsize or np.array((row_col_len, row_col_len)) * 4
    fig, ax = plt.subplots(row_col_len*5, row_col_len, figsize=figsize)
    for i in range(row_col_len*5):
        for j in range(row_col_len):
            batch_index = np.random.randint(0, BATCH_SIZE/2)
            output_classes = np.array(datagen[batch_index][1]['class_out'])
            classes_true = np.where(output_classes == 1)[0]
            sample_index = classes_true[np.random.randint(0, classes_true.shape[0])]
            image = datagen[batch_index][0][sample_index]
            print(image.shape)
            box = datagen[batch_index][1]['box_out'][sample_index]
            plotted_box = plot_bbox(image, box, norm=True)
            ax[i,j].imshow(plotted_box)
            ax[i,j].set_axis_off()
            #ax[i,j].title.set_text(str(batch_index*BATCH_SIZE+sample_index))
    plt.show()
    


# Function to make a prediction during training
def visualize_prediction(model, data):    
    # Select a sample where an object exists
    output_classes = np.array(custom_test_gen[0][1]['class_out'])
    sample_index = np.where(output_classes == 1)[0]
    sample_index = sample_index[0] if sample_index[0] else 0 
    
    # Get image
    image = np.array([data[0][0][sample_index]])
    
    # Set y_true & y_pred for class & bounding box
    yt_box = np.array([custom_test_gen[0][1]['box_out'][sample_index]])
    yt_class = np.array([custom_test_gen[0][1]['class_out'][sample_index]])
    yp_class, yp_box = model.predict(image)

    # Plot bounding box on image & show it
    image_plotted = plot_bbox(image[0], yt_box[0], yp_box[0], norm=True) 
    plt.imshow(image_plotted)
    plt.axis('off')
    
    # Print y_true class & y_pred class
    print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
    plt.show()


# Function to reduce learning rate during training        
def lr_scheduler(epoch, lr):
    if epoch > 10:
        lr = lr * tf.math.exp(-0.05) #-0.1
        print(lr)
    return float(lr)

# %%
# Read CSV
train_dataset = pd.read_csv('./images/train/dataset2.csv')
train_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']
test_dataset = pd.read_csv('./images/test/dataset2.csv')
test_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']


# List directories of files
train_image_dir_hand = Path('./images/train')
train_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))
test_image_dir_hand = Path('./images/test')
test_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))

# Create dataframe of {paths, labels}
train_df_hand = grabPaths(train_filepaths_hand)
test_df_hand = grabPaths(test_filepaths_hand)

train_dataset['path'] = "./images/train/" + train_dataset['path']
test_dataset['path'] = "./images/test/" + test_dataset['path']


# Resize boxes, keep zeros if no object exists
train_dataset.iloc[:,2:] = resize_boxes(train_dataset.iloc[:,2:])
test_dataset.iloc[:,2:] = resize_boxes(test_dataset.iloc[:,2:])

# %%
ax = sns.countplot(x='ball_exists', data=train_dataset)
ax.set(xlabel='Object exists in image', ylabel='No. of Image')
# Out:
# [Text(0.5, 0, 'Object exists in image'), Text(0, 0.5, 'No. of Image')]

# %%
# balance dataset (undersampling)
# balls = dataset[dataset['ball_exists'] == 1]
# noballs = dataset[dataset['ball_exists'] == 0]
# balls = balls.sample(frac=0.75).reset_index(drop=True)

# # merge balanced classes & shuffle
# train_df = pd.concat((balls, noballs)).sample(frac=1.).reset_index(drop=True)

# train_df, test_df = train_test_split(train_df, test_size=0.2)

# print(f"No. Training Samples: {train_df.shape[0]}\nNo. Validation Samples: {test_df.shape[0]}")

# %%
# Create custom Generator for multiple output models
class MultiOutputGen(tf.keras.utils.Sequence):
    def __init__(self, input_gen, output_gen):
        self.inpgen = input_gen
        self.outgen = output_gen
#         assert len(input_gen) == len(output_gen)

    def __len__(self):
        return len(self.inpgen)

    def __getitem__(self, i):
        images = self.inpgen[i]
        start = i * images.shape[0]
        end = (i+1) * images.shape[0]
        classes_num = self.outgen.iloc[start:end,0].values
        x = self.outgen.iloc[start:end,1]
        y = self.outgen.iloc[start:end,2]
        w = self.outgen.iloc[start:end,3]
#         h = self.outgen.iloc[start:end,4]
        return images, {'class_out':classes_num, 'box_out':np.array([x, y, w]).T}

    def on_epoch_end(self):
        self.inpgen.on_epoch_end()
    
# Class to visualize predictions during training
class ConvergenceVisualization(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        global custom_test_gen
        visualize_prediction(self.model, custom_test_gen)

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    #brightness_range=(0.8, 1.2),
    rescale = 1./255.,
    #dtype=tf.uint8,
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255.,
    #dtype=tf.uint8,
)

train_images = train_generator.flow_from_dataframe(
    dataframe=train_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

# Create multi-output generator
custom_train_gen = MultiOutputGen(train_images, train_dataset.iloc[:,1:])
custom_test_gen = MultiOutputGen(test_images, test_dataset.iloc[:,1:])
# Out:
# Found 3006 validated image filenames.
# Found 527 validated image filenames.

# %%
#visualize_samples(custom_train_gen, 2)

# %%
# BEST MODEL

inp = Input(shape=(IMG_HEIGHT,IMG_WIDTH,3), name='image')

X = SeparableConv2D(64, (7,7), strides=2, padding='valid')(inp)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = SeparableConv2D(192, (3,3), strides=1, padding='same')(X)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = convblock(X, [16, 16, 16], pool='max')
X = convblock(X, [32, 32, 32], pool='max')
X = convblock(X, [64, 64, 64], pool='max')
X = convblock(X, [128, 128, 128], pool='max')
X = convblock(X, [256, 256, 256])

X = Flatten()(X)
boxX = Dense(512)(X)
boxX = LeakyReLU()(boxX)

classX = Dense(128)(X)
classX = LeakyReLU()(classX)

box_out = Dense(3, name='box_out')(boxX)
class_out = Dense(1, name='class_out', activation='sigmoid')(classX)


model = Model(inp, [class_out, box_out])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 264, 640, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d              │ (None, 129, 317, 64)      │             403 │ image[0][0]                │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 158, 64)       │               0 │ separable_conv2d[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_1            │ (None, 64, 158, 192)      │          13,056 │ max_pooling2d[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 79, 192)       │               0 │ separable_conv2d_1[0][0]   │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_2            │ (None, 32, 79, 16)        │           4,816 │ max_pooling2d_1[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 32, 79, 16)        │              64 │ separable_conv2d_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 32, 79, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_3            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu[0][0]          │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_4            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu_1[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 79, 16)        │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ separable_conv2d_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 39, 16)        │               0 │ leaky_re_lu_2[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_5            │ (None, 16, 39, 32)        │             688 │ max_pooling2d_2[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_6            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_3[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_7            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_4[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 16, 39, 32)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ separable_conv2d_5[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 8, 19, 32)         │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_8            │ (None, 8, 19, 64)         │           2,400 │ max_pooling2d_3[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_8[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_9            │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_6[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_9[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_10           │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_7[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_10[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 8, 19, 64)         │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ separable_conv2d_8[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 4, 9, 64)          │               0 │ leaky_re_lu_8[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_11           │ (None, 4, 9, 128)         │           8,896 │ max_pooling2d_4[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 4, 9, 128)         │             512 │ separable_conv2d_11[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 4, 9, 128)         │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_12           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_9[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_12[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_13           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_10[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_13[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 4, 9, 128)         │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ separable_conv2d_11[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 2, 4, 128)         │               0 │ leaky_re_lu_11[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_14           │ (None, 2, 4, 256)         │          34,176 │ max_pooling2d_5[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_14[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_12 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_15           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_12[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_15[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_13 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_16           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_13[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_16[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 2, 4, 256)         │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ separable_conv2d_14[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_14 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2048)              │               0 │ leaky_re_lu_14[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │         262,272 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 512)               │       1,049,088 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_16 (LeakyReLU)    │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_15 (LeakyReLU)    │ (None, 512)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_out (Dense)             │ (None, 1)                 │             129 │ leaky_re_lu_16[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ box_out (Dense)               │ (None, 3)                 │           1,539 │ leaky_re_lu_15[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,567,927 (5.98 MB)
#  Trainable params: 1,564,951 (5.97 MB)
#  Non-trainable params: 2,976 (11.62 KB)

# %%
adam = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Function to calculate MSE Loss function
# for samples where object exists
@keras.saving.register_keras_serializable(package="custom_package", name="custom_mse")
def custom_mse(y_true, y_pred):
    print("mse y_pred: ", y_pred)
    mask = K.not_equal(K.sum(y_true, axis=1), 0.0)
    y_true_custom = y_true[mask]
    y_pred_custom = y_pred[mask]
    print("mse y_pred_custom: ", y_pred_custom)
    mse = tf.keras.losses.MeanSquaredError()
    result = mse(y_true_custom, y_pred_custom) # * 0.3
    print("mse result: ", result)
    return result

model.compile(
    loss={
        "box_out":custom_mse,
        'class_out':'binary_crossentropy'
    },
    metrics={
        'class_out':'accuracy'
    },
    optimizer=adam
)

# %%
history = model.fit(
    custom_train_gen,
    epochs=EPOCHS,
    validation_data=custom_test_gen,
    callbacks=[
        tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
        ConvergenceVisualization()
    ]
)
# Out:
# C:\Users\Salkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# mse y_pred:  Tensor("functional_1/box_out_1/BiasAdd:0", shape=(None, 3), dtype=float32)
# mse y_pred_custom:  Tensor("compile_loss/custom_mse/boolean_mask_1/GatherV2:0", shape=(None, 3), dtype=float32)
# mse result:  Tensor("compile_loss/custom_mse/mean_squared_error/div_no_nan:0", shape=(), dtype=float32)
# mse y_pred:  Tensor("functional_1/box_out_1/BiasAdd:0", shape=(None, 3), dtype=float32)
# mse y_pred_custom:  Tensor("compile_loss/custom_mse/boolean_mask_1/GatherV2:0", shape=(None, 3), dtype=float32)
# mse result:  Tensor("compile_loss/custom_mse/mean_squared_error/div_no_nan:0", shape=(), dtype=float32)
# mse y_pred:  Tensor("functional_1/box_out_1/BiasAdd:0", shape=(None, 3), dtype=float32)ss: 13096.7256 - class_out_accuracy: 0.5771 - class_out_loss: 11.1289 - loss: 13379.8281
# mse y_pred_custom:  Tensor("compile_loss/custom_mse/boolean_mask_1/GatherV2:0", shape=(None, 3), dtype=float32)
# mse result:  Tensor("compile_loss/custom_mse/mean_squared_error/div_no_nan:0", shape=(), dtype=float32)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Class: y_true= [1]  | y_pred= 1
# C:\Users\Salkin\AppData\Local\Temp\ipykernel_36040\1070830706.py:124: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 29s 948ms/step - box_out_loss: 12842.3027 - class_out_accuracy: 0.5765 - class_out_loss: 10.9710 - loss: 13120.2910 - val_box_out_loss: 16847.9902 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.7301 - val_loss: 10738.3662 - learning_rate: 0.0055
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 3178.9893 - class_out_accuracy: 0.7819 - class_out_loss: 4.1528 - loss: 3300.7681
# Class: y_true= [1]  | y_pred= 1
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 911ms/step - box_out_loss: 3249.2415 - class_out_accuracy: 0.7743 - class_out_loss: 4.1694 - loss: 3370.6699 - val_box_out_loss: 14829.3105 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.7230 - val_loss: 9420.7969 - learning_rate: 0.0055
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 2102.1143 - class_out_accuracy: 0.6789 - class_out_loss: 1.4228 - loss: 2114.8315
# Class: y_true= [1]  | y_pred= 1
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 23s 951ms/step - box_out_loss: 2145.6218 - class_out_accuracy: 0.6776 - class_out_loss: 1.4147 - loss: 2160.6812 - val_box_out_loss: 13030.4199 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.8419 - val_loss: 8254.9326 - learning_rate: 0.0055
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 3593.2444 - class_out_accuracy: 0.6670 - class_out_loss: 1.3462 - loss: 3617.4065
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 898ms/step - box_out_loss: 3539.9480 - class_out_accuracy: 0.6668 - class_out_loss: 1.3601 - loss: 3565.1987 - val_box_out_loss: 11779.1816 - val_class_out_accuracy: 0.7306 - val_class_out_loss: 0.6767 - val_loss: 7476.9048 - learning_rate: 0.0055
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 2346.7283 - class_out_accuracy: 0.4821 - class_out_loss: 1.2015 - loss: 2351.5544
# Class: y_true= [1]  | y_pred= 1
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 895ms/step - box_out_loss: 2328.6628 - class_out_accuracy: 0.4865 - class_out_loss: 1.1943 - loss: 2335.0020 - val_box_out_loss: 10891.4590 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.7666 - val_loss: 6910.7461 - learning_rate: 0.0055
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1145.0566 - class_out_accuracy: 0.6466 - class_out_loss: 0.7415 - loss: 1192.1053
# Class: y_true= [1]  | y_pred= 1
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 927ms/step - box_out_loss: 1176.2850 - class_out_accuracy: 0.6447 - class_out_loss: 0.7514 - loss: 1223.1832 - val_box_out_loss: 10236.7012 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.8409 - val_loss: 6511.7461 - learning_rate: 0.0055
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/steptep - box_out_loss: 3024.6899 - class_out_accuracy: 0.8343 - class_out_loss: 0.6578 - loss: 3148.1499
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 906ms/step - box_out_loss: 3007.2095 - class_out_accuracy: 0.8279 - class_out_loss: 0.6646 - loss: 3128.0369 - val_box_out_loss: 9923.2764 - val_class_out_accuracy: 0.7306 - val_class_out_loss: 0.6703 - val_loss: 6194.4326 - learning_rate: 0.0055
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1864.6406 - class_out_accuracy: 0.6864 - class_out_loss: 0.6603 - loss: 1877.3092
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 903ms/step - box_out_loss: 1862.5442 - class_out_accuracy: 0.6858 - class_out_loss: 0.6601 - loss: 1876.3239 - val_box_out_loss: 8612.5410 - val_class_out_accuracy: 0.7306 - val_class_out_loss: 0.6849 - val_loss: 5423.8101 - learning_rate: 0.0055
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1284.6582 - class_out_accuracy: 0.6322 - class_out_loss: 0.7965 - loss: 1298.1776
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 902ms/step - box_out_loss: 1294.4753 - class_out_accuracy: 0.6295 - class_out_loss: 0.7969 - loss: 1308.8301 - val_box_out_loss: 7727.8936 - val_class_out_accuracy: 0.7306 - val_class_out_loss: 0.7256 - val_loss: 4574.8242 - learning_rate: 0.0055
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 423.0510 - class_out_accuracy: 0.8956 - class_out_loss: 0.3968 - loss: 426.5685
# Class: y_true= [1]  | y_pred= 1
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 909ms/step - box_out_loss: 453.9185 - class_out_accuracy: 0.8901 - class_out_loss: 0.4082 - loss: 458.3715 - val_box_out_loss: 8467.9238 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.7230 - val_loss: 5294.4199 - learning_rate: 0.0055
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1262.9507 - class_out_accuracy: 0.4928 - class_out_loss: 1.0904 - loss: 1311.6677
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 908ms/step - box_out_loss: 1291.1497 - class_out_accuracy: 0.4946 - class_out_loss: 1.0845 - loss: 1339.6842 - val_box_out_loss: 14818.3467 - val_class_out_accuracy: 0.7324 - val_class_out_loss: 0.7727 - val_loss: 14024.0459 - learning_rate: 0.0055
# tf.Tensor(0.005128166, shape=(), dtype=float32)
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1514.5736 - class_out_accuracy: 0.6403 - class_out_loss: 0.7409 - loss: 1521.9672
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 21s 890ms/step - box_out_loss: 1527.5488 - class_out_accuracy: 0.6387 - class_out_loss: 0.7409 - loss: 1536.2916 - val_box_out_loss: 7453.0093 - val_class_out_accuracy: 0.7438 - val_class_out_loss: 0.7396 - val_loss: 4787.0947 - learning_rate: 0.0051
# tf.Tensor(0.0047814706, shape=(), dtype=float32)
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1115.7003 - class_out_accuracy: 0.6874 - class_out_loss: 0.5934 - loss: 1166.4463
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 904ms/step - box_out_loss: 1124.0868 - class_out_accuracy: 0.6863 - class_out_loss: 0.5949 - loss: 1173.9923 - val_box_out_loss: 5749.1392 - val_class_out_accuracy: 0.7932 - val_class_out_loss: 0.6686 - val_loss: 3053.6606 - learning_rate: 0.0048
# tf.Tensor(0.0044582137, shape=(), dtype=float32)
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1085.1647 - class_out_accuracy: 0.7489 - class_out_loss: 0.5705 - loss: 1086.7401
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 902ms/step - box_out_loss: 1085.6847 - class_out_accuracy: 0.7491 - class_out_loss: 0.5702 - loss: 1088.1843 - val_box_out_loss: 6547.8711 - val_class_out_accuracy: 0.7381 - val_class_out_loss: 0.7091 - val_loss: 3557.3174 - learning_rate: 0.0045
# tf.Tensor(0.004156811, shape=(), dtype=float32)
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 842.3038 - class_out_accuracy: 0.7418 - class_out_loss: 0.6193 - loss: 873.5215
# how!!!!!!!!!!!!!!!!!!!!
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 904ms/step - box_out_loss: 865.1830 - class_out_accuracy: 0.7361 - class_out_loss: 0.6253 - loss: 896.4255 - val_box_out_loss: 11204.2871 - val_class_out_accuracy: 0.7552 - val_class_out_loss: 0.6858 - val_loss: 5812.6997 - learning_rate: 0.0042
# tf.Tensor(0.0038757853, shape=(), dtype=float32)
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 1033.8677 - class_out_accuracy: 0.7611 - class_out_loss: 0.5637 - loss: 1061.6547
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 893ms/step - box_out_loss: 1052.1936 - class_out_accuracy: 0.7578 - class_out_loss: 0.5657 - loss: 1080.2043 - val_box_out_loss: 4745.7383 - val_class_out_accuracy: 0.7666 - val_class_out_loss: 0.6973 - val_loss: 2094.3914 - learning_rate: 0.0039
# tf.Tensor(0.0036137584, shape=(), dtype=float32)
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1111.8558 - class_out_accuracy: 0.7109 - class_out_loss: 0.5896 - loss: 1115.3805
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 915ms/step - box_out_loss: 1110.0131 - class_out_accuracy: 0.7104 - class_out_loss: 0.5895 - loss: 1114.3566 - val_box_out_loss: 4409.7773 - val_class_out_accuracy: 0.7362 - val_class_out_loss: 0.7661 - val_loss: 1792.0519 - learning_rate: 0.0036
# tf.Tensor(0.0033694461, shape=(), dtype=float32)
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 965.8964 - class_out_accuracy: 0.6798 - class_out_loss: 0.5950 - loss: 1012.6142
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 897ms/step - box_out_loss: 965.6277 - class_out_accuracy: 0.6807 - class_out_loss: 0.5951 - loss: 1011.3433 - val_box_out_loss: 4722.0405 - val_class_out_accuracy: 0.7400 - val_class_out_loss: 0.7653 - val_loss: 1860.9543 - learning_rate: 0.0034
# tf.Tensor(0.003141651, shape=(), dtype=float32)
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 857.0398 - class_out_accuracy: 0.6746 - class_out_loss: 0.5550 - loss: 862.4911
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 918ms/step - box_out_loss: 852.4077 - class_out_accuracy: 0.6735 - class_out_loss: 0.5574 - loss: 858.3166 - val_box_out_loss: 4619.6768 - val_class_out_accuracy: 0.7362 - val_class_out_loss: 0.7442 - val_loss: 1689.3147 - learning_rate: 0.0031
# tf.Tensor(0.002929256, shape=(), dtype=float32)
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 358.3556 - class_out_accuracy: 0.6833 - class_out_loss: 0.5333 - loss: 366.6613
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 919ms/step - box_out_loss: 359.2973 - class_out_accuracy: 0.6831 - class_out_loss: 0.5335 - loss: 367.6281 - val_box_out_loss: 4392.6021 - val_class_out_accuracy: 0.7761 - val_class_out_loss: 0.6936 - val_loss: 1496.1085 - learning_rate: 0.0029
# tf.Tensor(0.0027312203, shape=(), dtype=float32)
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 607.4991 - class_out_accuracy: 0.5597 - class_out_loss: 0.6828 - loss: 609.7358
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 911ms/step - box_out_loss: 597.9800 - class_out_accuracy: 0.5648 - class_out_loss: 0.6777 - loss: 600.4742 - val_box_out_loss: 5034.2725 - val_class_out_accuracy: 0.7590 - val_class_out_loss: 0.8236 - val_loss: 1606.7720 - learning_rate: 0.0027
# tf.Tensor(0.002546573, shape=(), dtype=float32)
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 331.3972 - class_out_accuracy: 0.8257 - class_out_loss: 0.4059 - loss: 346.5450
# Class: y_true= [1]  | y_pred= 1
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 907ms/step - box_out_loss: 335.1725 - class_out_accuracy: 0.8221 - class_out_loss: 0.4115 - loss: 350.1107 - val_box_out_loss: 3853.0796 - val_class_out_accuracy: 0.5882 - val_class_out_loss: 0.6860 - val_loss: 1192.6229 - learning_rate: 0.0025
# tf.Tensor(0.002374409, shape=(), dtype=float32)
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 203.5744 - class_out_accuracy: 0.7241 - class_out_loss: 0.5519 - loss: 205.9889
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 908ms/step - box_out_loss: 204.5625 - class_out_accuracy: 0.7249 - class_out_loss: 0.5513 - loss: 207.1023 - val_box_out_loss: 3759.8020 - val_class_out_accuracy: 0.7533 - val_class_out_loss: 0.7187 - val_loss: 1208.8278 - learning_rate: 0.0024
# tf.Tensor(0.0022138844, shape=(), dtype=float32)
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 125.8700 - class_out_accuracy: 0.8015 - class_out_loss: 0.4281 - loss: 127.8169
# Class: y_true= [1]  | y_pred= 1
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 902ms/step - box_out_loss: 127.8406 - class_out_accuracy: 0.7989 - class_out_loss: 0.4317 - loss: 129.8842 - val_box_out_loss: 4013.0859 - val_class_out_accuracy: 0.6110 - val_class_out_loss: 0.7110 - val_loss: 1525.5260 - learning_rate: 0.0022
# tf.Tensor(0.0020642122, shape=(), dtype=float32)
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 181.8995 - class_out_accuracy: 0.8249 - class_out_loss: 0.4417 - loss: 183.1825
# Class: y_true= [1]  | y_pred= 1
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 906ms/step - box_out_loss: 186.2562 - class_out_accuracy: 0.8211 - class_out_loss: 0.4449 - loss: 187.7641 - val_box_out_loss: 4466.0254 - val_class_out_accuracy: 0.4383 - val_class_out_loss: 0.8027 - val_loss: 1711.1627 - learning_rate: 0.0021
# tf.Tensor(0.0019246588, shape=(), dtype=float32)
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 210.1659 - class_out_accuracy: 0.6825 - class_out_loss: 0.5739 - loss: 215.8487
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 907ms/step - box_out_loss: 209.5274 - class_out_accuracy: 0.6844 - class_out_loss: 0.5712 - loss: 215.1737 - val_box_out_loss: 3792.4429 - val_class_out_accuracy: 0.7059 - val_class_out_loss: 0.7471 - val_loss: 1184.9720 - learning_rate: 0.0019
# tf.Tensor(0.00179454, shape=(), dtype=float32)
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 165.8333 - class_out_accuracy: 0.8025 - class_out_loss: 0.4528 - loss: 171.0247
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 907ms/step - box_out_loss: 164.3116 - class_out_accuracy: 0.8045 - class_out_loss: 0.4506 - loss: 169.4235 - val_box_out_loss: 3630.7532 - val_class_out_accuracy: 0.6622 - val_class_out_loss: 0.8270 - val_loss: 1128.1938 - learning_rate: 0.0018
# tf.Tensor(0.001673218, shape=(), dtype=float32)
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 88.8646 - class_out_accuracy: 0.8611 - class_out_loss: 0.3343 - loss: 91.4297
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 902ms/step - box_out_loss: 89.5031 - class_out_accuracy: 0.8598 - class_out_loss: 0.3366 - loss: 92.0735 - val_box_out_loss: 3802.8477 - val_class_out_accuracy: 0.6167 - val_class_out_loss: 0.8337 - val_loss: 1071.3167 - learning_rate: 0.0017
# tf.Tensor(0.0015600981, shape=(), dtype=float32)
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 81.7022 - class_out_accuracy: 0.8632 - class_out_loss: 0.3245 - loss: 82.7958
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 908ms/step - box_out_loss: 82.2794 - class_out_accuracy: 0.8612 - class_out_loss: 0.3273 - loss: 83.4290 - val_box_out_loss: 3610.3501 - val_class_out_accuracy: 0.5750 - val_class_out_loss: 0.8490 - val_loss: 1044.5287 - learning_rate: 0.0016
# tf.Tensor(0.0014546259, shape=(), dtype=float32)
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 84.9622 - class_out_accuracy: 0.8235 - class_out_loss: 0.3666 - loss: 85.6745
# Class: y_true= [1]  | y_pred= 0
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 22s 905ms/step - box_out_loss: 84.9754 - class_out_accuracy: 0.8227 - class_out_loss: 0.3680 - loss: 85.7497 - val_box_out_loss: 3788.5835 - val_class_out_accuracy: 0.5047 - val_class_out_loss: 0.8594 - val_loss: 1180.5590 - learning_rate: 0.0015

# %%
# Accuracy & Loss Visualization

#  Overall Loss
train_overall_loss = history.history['loss']
val_overall_loss = history.history['val_loss']

# Classification Accuracy
train_classification_acc = history.history['class_out_accuracy']
val_classification_acc = history.history['val_class_out_accuracy']

# Classification Loss
train_classification_loss = history.history['class_out_loss']
val_classification_loss = history.history['val_class_out_loss']

# Bounding Box Loss
train_bbox_loss = history.history['box_out_loss']
val_bbox_loss = history.history['val_box_out_loss']

epochs = range(1, len(history.history['loss'])+1)

f, ax = plt.subplots(nrows=2,ncols=2,figsize=(18,15))
    
ax[0,0].plot(epochs, train_overall_loss,  marker='o', label='Training')
ax[0,0].plot(epochs, val_overall_loss, marker='o', color = 'green', label='Validation')
ax[0,0].set_title('Overall Loss')
ax[0,0].set_xlabel('Epochs')
ax[0,0].set_ylabel('Loss')
ax[0,0].legend(loc='best')
ax[0,0].grid(True)

ax[0,1].plot(epochs, train_bbox_loss, marker='o', label='Training')
ax[0,1].plot(epochs, val_bbox_loss, marker='o', color = 'green', label='Validation')
ax[0,1].set_title('Bounding Box Loss')
ax[0,1].set_xlabel('Epochs')
ax[0,1].set_ylabel('Loss')
ax[0,1].legend(loc='best')
ax[0,1].grid(True)



ax[1,0].plot(epochs, train_classification_acc,  marker='o', label='Training')
ax[1,0].plot(epochs, val_classification_acc, marker='o', color = 'green', label='Validation')
ax[1,0].set_title('Classification Accuracy')
ax[1,0].set_xlabel('Epochs')
ax[1,0].set_ylabel('Accuracy')
ax[1,0].legend(loc='best')
ax[1,0].grid(True)

ax[1,1].plot(epochs, train_classification_loss, marker='o', label='Training')
ax[1,1].plot(epochs, val_classification_loss, marker='o', color = 'green', label='Validation')
ax[1,1].set_title('Classification Loss')
ax[1,1].set_xlabel('Epochs')
ax[1,1].set_ylabel('Loss')
ax[1,1].legend(loc='best')
ax[1,1].grid(True)

plt.show()
f.savefig('LossAndAccuracy.eps', format='eps')
plt.close()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#model.save("test1 ball detection.h5")
model.save("ball_detection_V5.keras")

# %%
#converter = tf.lite.TFLiteConverter.from_keras_model(model)
#tflite_model = converter.convert()
#open("ball_detection_V2.tflite", "wb").write(tflite_model)

# %%
@keras.saving.register_keras_serializable(package="custom_package", name="custom_mse")
def custom_mse(y_true, y_pred):
    print("mse y_pred: ", y_pred)
    mask = K.not_equal(K.sum(y_true, axis=1), 0.0)
    y_true_custom = y_true[mask]
    y_pred_custom = y_pred[mask]
    print("mse y_pred_custom: ", y_pred_custom)
    mse = tf.keras.losses.MeanSquaredError()
    result = mse(y_true_custom, y_pred_custom) # * 0.3
    print("mse result: ", result)
    return result
new_model = tf.keras.models.load_model("ball_detection_V5.keras")
new_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 264, 640, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d              │ (None, 129, 317, 64)      │             403 │ image[0][0]                │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 158, 64)       │               0 │ separable_conv2d[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_1            │ (None, 64, 158, 192)      │          13,056 │ max_pooling2d[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 79, 192)       │               0 │ separable_conv2d_1[0][0]   │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_2            │ (None, 32, 79, 16)        │           4,816 │ max_pooling2d_1[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 32, 79, 16)        │              64 │ separable_conv2d_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 32, 79, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_3            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu[0][0]          │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_4            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu_1[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 79, 16)        │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ separable_conv2d_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 39, 16)        │               0 │ leaky_re_lu_2[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_5            │ (None, 16, 39, 32)        │             688 │ max_pooling2d_2[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_6            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_3[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_7            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_4[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 16, 39, 32)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ separable_conv2d_5[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 8, 19, 32)         │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_8            │ (None, 8, 19, 64)         │           2,400 │ max_pooling2d_3[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_8[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_9            │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_6[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_9[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_10           │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_7[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_10[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 8, 19, 64)         │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ separable_conv2d_8[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 4, 9, 64)          │               0 │ leaky_re_lu_8[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_11           │ (None, 4, 9, 128)         │           8,896 │ max_pooling2d_4[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 4, 9, 128)         │             512 │ separable_conv2d_11[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 4, 9, 128)         │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_12           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_9[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_12[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_13           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_10[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_13[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 4, 9, 128)         │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ separable_conv2d_11[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 2, 4, 128)         │               0 │ leaky_re_lu_11[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_14           │ (None, 2, 4, 256)         │          34,176 │ max_pooling2d_5[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_14[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_12 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_15           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_12[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_15[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_13 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_16           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_13[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_16[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 2, 4, 256)         │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ separable_conv2d_14[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_14 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2048)              │               0 │ leaky_re_lu_14[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │         262,272 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 512)               │       1,049,088 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_16 (LeakyReLU)    │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_15 (LeakyReLU)    │ (None, 512)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_out (Dense)             │ (None, 1)                 │             129 │ leaky_re_lu_16[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ box_out (Dense)               │ (None, 3)                 │           1,539 │ leaky_re_lu_15[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,697,831 (17.92 MB)
#  Trainable params: 1,564,951 (5.97 MB)
#  Non-trainable params: 2,976 (11.62 KB)
#  Optimizer params: 3,129,904 (11.94 MB)

# %%
#def representative_dataset():
#    c = 0
#    test_images.reset()
#    for ind in range (len(test_images.filenames)):
#        #data_list = []
#        try:
#            data = test_images[ind]
#        #print(data)
#        #data_list.append(data[0])
#
#            for i in range(BATCH_SIZE):
#                c+=1
#        # now, data_array is the numeric data of whole images
#                data_array = np.asarray(data[i])*255
#                data_array = np.expand_dims(data_array, axis=0)
#        #print(data_array.shape)
#        #data_array=np.squeeze(data_array,axis=0)
#        #print(data_array.shape)
#        
#                yield [np.array(data_array, dtype=np.float32, ndmin=2)]
#        except:
#            print(c)
#            break

#converter = tf.lite.TFLiteConverter.from_keras_model(new_model)
#converter.optimizations = [tf.lite.Optimize.DEFAULT]
#converter.experimental_new_quantizer = True
#converter.representative_dataset = representative_dataset
#converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
#converter.inference_input_type = tf.uint8
#converter.inference_output_type = tf.uint8
#tflite_model = converter.convert()
#open("ball_detection_uint8.tflite", "wb").write(tflite_model)

# %%
#interpreter = tf.lite.Interpreter(model_path='ball_detection_uint8.tflite')
#interpreter.allocate_tensors()
#input_details = interpreter.get_input_details()
#output_details = interpreter.get_output_details()
#input_data = image = np.expand_dims(np.asarray(Image.open("./images/valid/frame598.jpg")), axis=0)
#interpreter.set_tensor(input_details[0]['index'], input_data)
#interpreter.invoke()
#output_data = interpreter.get_tensor(output_details[0]['index'])
#print(output_data)
#output_data = interpreter.get_tensor(output_details[1]['index'])
#print(output_data)

# %%
valid_dataset = pd.read_csv('./images/valid/dataset.csv')
#print(valid_dataset)
def visualize_evaluation(model, name):    
    # Get image
    im = Image.open("./images/valid/"+name)
    image = np.expand_dims(np.asarray(im)/255, axis=0)
    #image = np.expand_dims(np.asarray(im)/255, axis=0)
    print(image.shape)
    #print(image)
    
    # Set y_true & y_pred for class & bounding box
    print(valid_dataset.loc[valid_dataset['path']==name]['x'], valid_dataset.loc[valid_dataset['path']==name]['y'], valid_dataset.loc[valid_dataset['path']==name]['w'])
    yt_box = np.array([valid_dataset.loc[valid_dataset['path']==name]['x'], valid_dataset.loc[valid_dataset['path']==name]['y'], valid_dataset.loc[valid_dataset['path']==name]['w']])
    yt_class = np.array(valid_dataset.loc[valid_dataset['path']==name]['ball_exists'])
    
    yp_class, yp_box = model.predict(image)
    print(yp_class, yp_box)

    camera_fov = 120
    angle = (yp_box[0][0]+yp_box[0][2]/2)/640 *camera_fov - camera_fov/2
    print("Ball Angle", angle)

    # Plot bounding box on image & show it
    image_plotted = plot_bbox(image[0], yt_box, yp_box[0], norm=True) #True?
    plt.imshow(image_plotted)
    plt.axis('off')
    
    # Print y_true class & y_pred class
    print("Class: y_true=", yt_class, " | y_pred=", int(yp_class[0][0] >= 0.5))
    plt.show()

# %%
visualize_evaluation(new_model, "frame643.jpg")
# Out:
# (1, 264, 640, 3)
# 1150    0
# Name: x, dtype: int64 1150    0
# Name: y, dtype: int64 1150    0
# Name: w, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# [[0.82920074]] [[326.4023    40.947483 255.93477 ]]
# Ball Angle 25.19432
# Class: y_true= [0]  | y_pred= 1

# %%
def visu_tets(sample_index):
    data = custom_test_gen
    image = np.array([data[0][0][sample_index]])
    yt_box = np.array([custom_test_gen[0][1]['box_out'][sample_index]])
    yt_class = np.array([custom_test_gen[0][1]['class_out'][sample_index]])
    yp_class, yp_box = model.predict(image)
    print(image.shape)
    print(image)
    print(image[0].shape)
    image_plotted = plot_bbox(image[0], yt_box[0], yp_box[0], norm=True) 
    plt.imshow(image_plotted)
    plt.axis('off')
    plt.show()

# %%
visu_tets(0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# (1, 264, 640, 3)
# [[[[0.29803923 0.32156864 0.3137255 ]
#    [0.29803923 0.32156864 0.3137255 ]
#    [0.2901961  0.3137255  0.30588236]
#    ...
#    [0.24705884 0.29803923 0.19607845]
#    [0.25490198 0.3019608  0.21568629]
#    [0.25882354 0.30588236 0.227451  ]]
#
#   [[0.29803923 0.32156864 0.3137255 ]
#    [0.29411766 0.31764707 0.30980393]
#    [0.2901961  0.3137255  0.30588236]
#    ...
#    [0.24705884 0.29803923 0.19607845]
#    [0.25490198 0.3019608  0.21568629]
#    [0.25882354 0.30588236 0.227451  ]]
#
#   [[0.29803923 0.32156864 0.3137255 ]
#    [0.29411766 0.31764707 0.30980393]
#    [0.2901961  0.3137255  0.30588236]
#    ...
#    [0.2509804  0.3019608  0.20000002]
#    [0.25490198 0.3019608  0.21568629]
#    [0.2627451  0.30980393 0.23137257]]
#
#   ...
#
#   [[0.3137255  0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    ...
#    [0.42352945 0.48627454 0.48627454]
#    [0.41960788 0.48235297 0.48235297]
#    [0.4156863  0.4784314  0.4784314 ]]
#
#   [[0.3137255  0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    ...
#    [0.42352945 0.48627454 0.48627454]
#    [0.41960788 0.48235297 0.48235297]
#    [0.4156863  0.4784314  0.4784314 ]]
#
#   [[0.3137255  0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    ...
#    [0.42352945 0.48627454 0.48627454]
#    [0.4156863  0.4784314  0.4784314 ]
#    [0.4156863  0.4784314  0.4784314 ]]]]
# (264, 640, 3)
