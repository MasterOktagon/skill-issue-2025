# %%
#import cv2
import os

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from pathlib import Path
from PIL import Image, ImageDraw
from tensorflow.keras import backend as K
import keras
#from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Add, Conv2D, SeparableConv2D
from tensorflow.keras.layers import BatchNormalization, AveragePooling2D
from tensorflow.keras.layers import LeakyReLU, MaxPooling2D, Flatten
from tensorflow.keras.models import Model

keras.saving.get_custom_objects().clear()

# %%
IMG_HEIGHT = 264
IMG_WIDTH = 640
X_FACTOR = 1
Y_FACTOR = 1
BATCH_SIZE = 128
EPOCHS = 30    # maybe mehr?
learning_rate = 0.0055    # 0.005
train_dataset_path = './images/train/'
test_dataset_path = './images/test/'

# %%
# Function to read images names and store them in a DataFrame
def grabPaths(filepath):
    labels = [str(filepath[i]).split("/")[-1] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='path').astype(str)
    
    # Concatenate filepaths and labels

    # Shuffle the DataFrame and reset index
    df = pd.DataFrame(filepath)
    
    return df

# Function to scale boxes coordinates (bacuase images are resized)
def resize_boxes(boxes):
    boxes = np.array(boxes).astype(np.float32)
    boxes = boxes * X_FACTOR
    return (np.rint(boxes)).astype(int)


# Function to draw bounding box given an image & coordinates
def plot_bbox(image, yt_box, yp_box=None, norm=False):
    # If image is normalized (/255.) reconstruct (inverse) the operation
    if norm:
        image = image * 255.
        image = image.astype("uint8")
    
    # Convert image to array if not converted
    try:
        pil_img = Image.fromarray(image)
    except:
        pil_img = Image.fromarray(image.astype('uint8'))
        
    draw_img = ImageDraw.Draw(pil_img)
    
    x1, y1, w = yt_box
    h = w
    x2, y2 = x1+w, y1+h
    draw_img.rectangle((x1, y1, x2, y2), outline='green')
    
    # If y_pred box is given, draw it
    if yp_box is not None:
        x1, y1, w = yp_box
        h = w
        x2, y2 = x1+w, y1+h
        draw_img.rectangle((x1, y1, x2+1, y2+1), outline='red')
    return pil_img


# Function to build convolutionl block
def convblock(previous_layer, n_filters, filter_windows=(3,3,3), padding='same', pool=None):
    # [DepthwiseConv -> BatchNorm -> LeakyReLU] x3 + Residual connection -> Pooling (optional)

    x = SeparableConv2D(n_filters[0], filter_windows[0], padding=padding)(previous_layer)
    x_short = x
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[1], filter_windows[1], padding=padding)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[2], filter_windows[2], padding=padding)(x)
    x = BatchNormalization()(x)
    x = Add()([x, x_short])
    x = LeakyReLU()(x)
    
    if pool == 'max':
        x = MaxPooling2D(pool_size=(2,2))(x)
    elif pool == 'avg':
        x = AveragePooling2D(pool_size=(2,2))(x)
    
    return x

# Function to show samples
def visualize_samples(datagen, row_col_len=4, figsize=None):
    figsize = figsize or np.array((row_col_len, row_col_len)) * 4
    fig, ax = plt.subplots(row_col_len*5, row_col_len, figsize=figsize)
    for i in range(row_col_len*5):
        for j in range(row_col_len):
            batch_index = np.random.randint(0, BATCH_SIZE/2)
            output_classes = np.array(datagen[batch_index][1]['class_out'])
            classes_true = np.where(output_classes == 1)[0]
            sample_index = classes_true[np.random.randint(0, classes_true.shape[0])]
            image = datagen[batch_index][0][sample_index]
            print(image.shape)
            box = datagen[batch_index][1]['box_out'][sample_index]
            plotted_box = plot_bbox(image, box, norm=True)
            ax[i,j].imshow(plotted_box)
            ax[i,j].set_axis_off()
            #ax[i,j].title.set_text(str(batch_index*BATCH_SIZE+sample_index))
    plt.show()
    


# Function to make a prediction during training
def visualize_prediction(model, data):    
    # Select a sample where an object exists
    output_classes = np.array(custom_test_gen[0][1]['class_out'])
    sample_index = np.where(output_classes == 1)[0]
    sample_index = sample_index[0] if sample_index[0] else 0 
    
    # Get image
    image = np.array([data[0][0][sample_index]])
    
    # Set y_true & y_pred for class & bounding box
    yt_box = np.array([custom_test_gen[0][1]['box_out'][sample_index]])
    yt_class = np.array([custom_test_gen[0][1]['class_out'][sample_index]])
    yp_class, yp_box = model.predict(image)

    # Plot bounding box on image & show it
    image_plotted = plot_bbox(image[0], yt_box[0], yp_box[0], norm=True) 
    plt.imshow(image_plotted)
    plt.axis('off')
    
    # Print y_true class & y_pred class
    print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
    plt.show()


# Function to reduce learning rate during training        
def lr_scheduler(epoch, lr):
    if epoch > 10:
        lr = lr * tf.math.exp(-0.1) #-0.15
        print(lr)
    return float(lr)

# %%
# Read CSV
train_dataset = pd.read_csv('./images/train/dataset2.csv')
train_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']
test_dataset = pd.read_csv('./images/test/dataset2.csv')
test_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']


# List directories of files
train_image_dir_hand = Path('./images/train')
train_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))
test_image_dir_hand = Path('./images/test')
test_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))

# Create dataframe of {paths, labels}
train_df_hand = grabPaths(train_filepaths_hand)
test_df_hand = grabPaths(test_filepaths_hand)

train_dataset['path'] = "./images/train/" + train_dataset['path']
test_dataset['path'] = "./images/test/" + test_dataset['path']


# Resize boxes, keep zeros if no object exists
train_dataset.iloc[:,2:] = resize_boxes(train_dataset.iloc[:,2:])
test_dataset.iloc[:,2:] = resize_boxes(test_dataset.iloc[:,2:])

# %%
ax = sns.countplot(x='ball_exists', data=train_dataset)
ax.set(xlabel='Object exists in image', ylabel='No. of Image')
# Out:
# [Text(0.5, 0, 'Object exists in image'), Text(0, 0.5, 'No. of Image')]

# %%
# balance dataset (undersampling)
# balls = dataset[dataset['ball_exists'] == 1]
# noballs = dataset[dataset['ball_exists'] == 0]
# balls = balls.sample(frac=0.75).reset_index(drop=True)

# # merge balanced classes & shuffle
# train_df = pd.concat((balls, noballs)).sample(frac=1.).reset_index(drop=True)

# train_df, test_df = train_test_split(train_df, test_size=0.2)

# print(f"No. Training Samples: {train_df.shape[0]}\nNo. Validation Samples: {test_df.shape[0]}")

# %%
# Create custom Generator for multiple output models
class MultiOutputGen(tf.keras.utils.Sequence):
    def __init__(self, input_gen, output_gen):
        self.inpgen = input_gen
        self.outgen = output_gen
#         assert len(input_gen) == len(output_gen)

    def __len__(self):
        return len(self.inpgen)

    def __getitem__(self, i):
        images = self.inpgen[i]
        start = i * images.shape[0]
        end = (i+1) * images.shape[0]
        classes_num = self.outgen.iloc[start:end,0].values
        x = self.outgen.iloc[start:end,1]
        y = self.outgen.iloc[start:end,2]
        w = self.outgen.iloc[start:end,3]
#         h = self.outgen.iloc[start:end,4]
        return images, {'class_out':classes_num, 'box_out':np.array([x, y, w]).T}

    def on_epoch_end(self):
        self.inpgen.on_epoch_end()
    
# Class to visualize predictions during training
class ConvergenceVisualization(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        global custom_test_gen
        visualize_prediction(self.model, custom_test_gen)

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    #brightness_range=(0.8, 1.2),
    rescale = 1./255.,
    #dtype=tf.uint8,
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255.,
    #dtype=tf.uint8,
)

train_images = train_generator.flow_from_dataframe(
    dataframe=train_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

# Create multi-output generator
custom_train_gen = MultiOutputGen(train_images, train_dataset.iloc[:,1:])
custom_test_gen = MultiOutputGen(test_images, test_dataset.iloc[:,1:])
# Out:
# Found 4478 validated image filenames.
# Found 527 validated image filenames.

# %%
#visualize_samples(custom_train_gen, 2)

# %%
# BEST MODEL

inp = Input(shape=(IMG_HEIGHT,IMG_WIDTH,3), name='image')

X = SeparableConv2D(64, (7,7), strides=2, padding='valid')(inp)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = SeparableConv2D(192, (3,3), strides=1, padding='same')(X)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = convblock(X, [16, 16, 16], pool='max')
X = convblock(X, [32, 32, 32], pool='max')
X = convblock(X, [64, 64, 64], pool='max')
X = convblock(X, [128, 128, 128], pool='max')
X = convblock(X, [256, 256, 256])

X = Flatten()(X)
boxX = Dense(512)(X)
boxX = LeakyReLU()(boxX)

classX = Dense(128)(X)
classX = LeakyReLU()(classX)

box_out = Dense(3, name='box_out')(boxX)
class_out = Dense(1, name='class_out', activation='sigmoid')(classX)


model = Model(inp, [class_out, box_out])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 264, 640, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d              │ (None, 129, 317, 64)      │             403 │ image[0][0]                │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 158, 64)       │               0 │ separable_conv2d[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_1            │ (None, 64, 158, 192)      │          13,056 │ max_pooling2d[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 79, 192)       │               0 │ separable_conv2d_1[0][0]   │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_2            │ (None, 32, 79, 16)        │           4,816 │ max_pooling2d_1[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 32, 79, 16)        │              64 │ separable_conv2d_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 32, 79, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_3            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu[0][0]          │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_4            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu_1[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 79, 16)        │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ separable_conv2d_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 39, 16)        │               0 │ leaky_re_lu_2[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_5            │ (None, 16, 39, 32)        │             688 │ max_pooling2d_2[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_6            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_3[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_7            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_4[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 16, 39, 32)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ separable_conv2d_5[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 8, 19, 32)         │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_8            │ (None, 8, 19, 64)         │           2,400 │ max_pooling2d_3[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_8[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_9            │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_6[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_9[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_10           │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_7[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_10[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 8, 19, 64)         │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ separable_conv2d_8[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 4, 9, 64)          │               0 │ leaky_re_lu_8[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_11           │ (None, 4, 9, 128)         │           8,896 │ max_pooling2d_4[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 4, 9, 128)         │             512 │ separable_conv2d_11[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 4, 9, 128)         │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_12           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_9[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_12[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_13           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_10[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_13[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 4, 9, 128)         │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ separable_conv2d_11[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 2, 4, 128)         │               0 │ leaky_re_lu_11[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_14           │ (None, 2, 4, 256)         │          34,176 │ max_pooling2d_5[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_14[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_12 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_15           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_12[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_15[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_13 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_16           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_13[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_16[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 2, 4, 256)         │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ separable_conv2d_14[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_14 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2048)              │               0 │ leaky_re_lu_14[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │         262,272 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 512)               │       1,049,088 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_16 (LeakyReLU)    │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_15 (LeakyReLU)    │ (None, 512)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_out (Dense)             │ (None, 1)                 │             129 │ leaky_re_lu_16[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ box_out (Dense)               │ (None, 3)                 │           1,539 │ leaky_re_lu_15[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,567,927 (5.98 MB)
#  Trainable params: 1,564,951 (5.97 MB)
#  Non-trainable params: 2,976 (11.62 KB)

# %%
adam = tf.keras.optimizers.Adam(learning_rate=learning_rate)

# Function to calculate MSE Loss function
# for samples where object exists
@keras.saving.register_keras_serializable(package="custom_package", name="custom_mse")
def custom_mse(y_true, y_pred):
    mask = K.not_equal(K.sum(y_true, axis=1), 0.0)
    y_true_custom = y_true[mask]
    y_pred_custom = y_pred[mask]
    mse = tf.keras.losses.MeanSquaredError()
    result = mse(y_true_custom, y_pred_custom) # * 0.3
    return result

model.compile(
    loss={
        "box_out":custom_mse,
        'class_out':'binary_crossentropy'
    },
    metrics={
        'class_out':'accuracy'
    },
    optimizer=adam
)

# %%
history = model.fit(
    custom_train_gen,
    epochs=EPOCHS,
    validation_data=custom_test_gen,
    callbacks=[
        tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
        ConvergenceVisualization()
    ]
)
# Out:
# C:\Users\Salkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/stepep - box_out_loss: 12680.9473 - class_out_accuracy: 0.5154 - class_out_loss: 5.7596 - loss: 12687.6064
# Class: y_true= [1]  | y_pred= 0
# C:\Users\Salkin\AppData\Local\Temp\ipykernel_4604\3657912104.py:118: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 38s 929ms/step - box_out_loss: 12571.8682 - class_out_accuracy: 0.5184 - class_out_loss: 5.7957 - loss: 12578.6465 - val_box_out_loss: 17369.0039 - val_class_out_accuracy: 0.7306 - val_class_out_loss: 0.6724 - val_loss: 11081.3975 - learning_rate: 0.0055
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 4978.9785 - class_out_accuracy: 0.5171 - class_out_loss: 7.3949 - loss: 4993.3257
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 903ms/step - box_out_loss: 4963.9165 - class_out_accuracy: 0.5176 - class_out_loss: 7.3382 - loss: 4978.0688 - val_box_out_loss: 15854.3281 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.7028 - val_loss: 10090.9082 - learning_rate: 0.0055
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 3558.3496 - class_out_accuracy: 0.5775 - class_out_loss: 1.4205 - loss: 3561.7351
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 891ms/step - box_out_loss: 3560.9341 - class_out_accuracy: 0.5787 - class_out_loss: 1.4151 - loss: 3564.3047 - val_box_out_loss: 13902.9170 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.7698 - val_loss: 8820.2920 - learning_rate: 0.0055
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 3213.7690 - class_out_accuracy: 0.5777 - class_out_loss: 0.9319 - loss: 3217.0645
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 903ms/step - box_out_loss: 3216.9568 - class_out_accuracy: 0.5805 - class_out_loss: 0.9281 - loss: 3220.2241 - val_box_out_loss: 12234.7510 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 1.0762 - val_loss: 7744.3687 - learning_rate: 0.0055
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 2381.3816 - class_out_accuracy: 0.4317 - class_out_loss: 1.5154 - loss: 2384.9341
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 894ms/step - box_out_loss: 2394.0142 - class_out_accuracy: 0.4364 - class_out_loss: 1.5029 - loss: 2397.5327 - val_box_out_loss: 10182.9219 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 1.0174 - val_loss: 6426.0591 - learning_rate: 0.0055
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 2479.5510 - class_out_accuracy: 0.7588 - class_out_loss: 0.5953 - loss: 2483.4917
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 902ms/step - box_out_loss: 2476.8616 - class_out_accuracy: 0.7579 - class_out_loss: 0.5946 - loss: 2480.7385 - val_box_out_loss: 9400.8828 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.8055 - val_loss: 5897.8950 - learning_rate: 0.0055
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 2131.0522 - class_out_accuracy: 0.7408 - class_out_loss: 0.5809 - loss: 2131.9497
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 887ms/step - box_out_loss: 2130.0322 - class_out_accuracy: 0.7407 - class_out_loss: 0.5802 - loss: 2130.9460 - val_box_out_loss: 7559.4517 - val_class_out_accuracy: 0.2694 - val_class_out_loss: 0.7353 - val_loss: 4684.5112 - learning_rate: 0.0055
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 2262.8677 - class_out_accuracy: 0.7649 - class_out_loss: 0.5446 - loss: 2264.0723
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 896ms/step - box_out_loss: 2252.1714 - class_out_accuracy: 0.7642 - class_out_loss: 0.5451 - loss: 2253.3816 - val_box_out_loss: 7023.6826 - val_class_out_accuracy: 0.4763 - val_class_out_loss: 0.7163 - val_loss: 4010.9648 - learning_rate: 0.0055
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 1384.6957 - class_out_accuracy: 0.6429 - class_out_loss: 0.6215 - loss: 1385.5469
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 914ms/step - box_out_loss: 1390.3507 - class_out_accuracy: 0.6453 - class_out_loss: 0.6197 - loss: 1391.2135 - val_box_out_loss: 5794.9229 - val_class_out_accuracy: 0.3188 - val_class_out_loss: 0.9148 - val_loss: 2832.7676 - learning_rate: 0.0055
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 1503.7198 - class_out_accuracy: 0.7665 - class_out_loss: 0.5033 - loss: 1505.4213
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 913ms/step - box_out_loss: 1508.7662 - class_out_accuracy: 0.7653 - class_out_loss: 0.5049 - loss: 1510.4569 - val_box_out_loss: 4940.8330 - val_class_out_accuracy: 0.3833 - val_class_out_loss: 1.1265 - val_loss: 1691.2739 - learning_rate: 0.0055
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1318.8430 - class_out_accuracy: 0.7770 - class_out_loss: 0.5242 - loss: 1319.5956
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 908ms/step - box_out_loss: 1316.5160 - class_out_accuracy: 0.7758 - class_out_loss: 0.5252 - loss: 1317.2786 - val_box_out_loss: 5234.7900 - val_class_out_accuracy: 0.4194 - val_class_out_loss: 0.7217 - val_loss: 2307.9563 - learning_rate: 0.0055
# tf.Tensor(0.004976606, shape=(), dtype=float32)
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 996.5481 - class_out_accuracy: 0.7548 - class_out_loss: 0.5454 - loss: 997.1194
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 900ms/step - box_out_loss: 996.3041 - class_out_accuracy: 0.7543 - class_out_loss: 0.5460 - loss: 996.8877 - val_box_out_loss: 5417.3350 - val_class_out_accuracy: 0.3586 - val_class_out_loss: 0.8997 - val_loss: 2026.0023 - learning_rate: 0.0050
# tf.Tensor(0.004503019, shape=(), dtype=float32)
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 1023.4539 - class_out_accuracy: 0.7501 - class_out_loss: 0.5410 - loss: 1024.0149
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 904ms/step - box_out_loss: 1016.0702 - class_out_accuracy: 0.7493 - class_out_loss: 0.5421 - loss: 1016.6411 - val_box_out_loss: 5796.7354 - val_class_out_accuracy: 0.5655 - val_class_out_loss: 0.7368 - val_loss: 1892.0521 - learning_rate: 0.0045
# tf.Tensor(0.0040745004, shape=(), dtype=float32)
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 757.5659 - class_out_accuracy: 0.7327 - class_out_loss: 0.5495 - loss: 758.5480
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 920ms/step - box_out_loss: 757.7815 - class_out_accuracy: 0.7341 - class_out_loss: 0.5492 - loss: 758.7608 - val_box_out_loss: 4681.7437 - val_class_out_accuracy: 0.2789 - val_class_out_loss: 1.6147 - val_loss: 1226.3337 - learning_rate: 0.0041
# tf.Tensor(0.0036867606, shape=(), dtype=float32)
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 561.2025 - class_out_accuracy: 0.7884 - class_out_loss: 0.4703 - loss: 562.2590
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 906ms/step - box_out_loss: 558.7086 - class_out_accuracy: 0.7874 - class_out_loss: 0.4718 - loss: 559.7561 - val_box_out_loss: 4473.6611 - val_class_out_accuracy: 0.5028 - val_class_out_loss: 0.7650 - val_loss: 1204.7104 - learning_rate: 0.0037
# tf.Tensor(0.003335919, shape=(), dtype=float32)
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 330.5588 - class_out_accuracy: 0.7881 - class_out_loss: 0.4878 - loss: 331.3975
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 912ms/step - box_out_loss: 330.8910 - class_out_accuracy: 0.7882 - class_out_loss: 0.4870 - loss: 331.7234 - val_box_out_loss: 4343.1182 - val_class_out_accuracy: 0.3909 - val_class_out_loss: 0.8532 - val_loss: 908.5562 - learning_rate: 0.0033
# tf.Tensor(0.0030184644, shape=(), dtype=float32)
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 253.1552 - class_out_accuracy: 0.7481 - class_out_loss: 0.5162 - loss: 253.8453
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 911ms/step - box_out_loss: 254.4387 - class_out_accuracy: 0.7492 - class_out_loss: 0.5143 - loss: 255.1258 - val_box_out_loss: 4483.0967 - val_class_out_accuracy: 0.3321 - val_class_out_loss: 1.0649 - val_loss: 1091.3688 - learning_rate: 0.0030
# tf.Tensor(0.0027312196, shape=(), dtype=float32)
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 287.3692 - class_out_accuracy: 0.8113 - class_out_loss: 0.4181 - loss: 288.0391
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 907ms/step - box_out_loss: 287.3293 - class_out_accuracy: 0.8109 - class_out_loss: 0.4194 - loss: 287.9971 - val_box_out_loss: 4498.3193 - val_class_out_accuracy: 0.3472 - val_class_out_loss: 1.1765 - val_loss: 942.1744 - learning_rate: 0.0027
# tf.Tensor(0.0024713099, shape=(), dtype=float32)
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 191.9089 - class_out_accuracy: 0.8534 - class_out_loss: 0.3712 - loss: 192.5283
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 915ms/step - box_out_loss: 192.4591 - class_out_accuracy: 0.8527 - class_out_loss: 0.3738 - loss: 193.0770 - val_box_out_loss: 4492.2866 - val_class_out_accuracy: 0.3416 - val_class_out_loss: 0.9799 - val_loss: 936.2809 - learning_rate: 0.0025
# tf.Tensor(0.0022361337, shape=(), dtype=float32)
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 190.8237 - class_out_accuracy: 0.8543 - class_out_loss: 0.3911 - loss: 191.4767
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 920ms/step - box_out_loss: 190.5742 - class_out_accuracy: 0.8533 - class_out_loss: 0.3924 - loss: 191.2234 - val_box_out_loss: 4272.3110 - val_class_out_accuracy: 0.4649 - val_class_out_loss: 0.8033 - val_loss: 876.6499 - learning_rate: 0.0022
# tf.Tensor(0.0020233374, shape=(), dtype=float32)
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 147.0209 - class_out_accuracy: 0.8569 - class_out_loss: 0.4058 - loss: 147.5436
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 886ms/step - box_out_loss: 147.1183 - class_out_accuracy: 0.8566 - class_out_loss: 0.4057 - loss: 147.6395 - val_box_out_loss: 4353.6543 - val_class_out_accuracy: 0.4213 - val_class_out_loss: 0.8977 - val_loss: 909.7480 - learning_rate: 0.0020
# tf.Tensor(0.0018307915, shape=(), dtype=float32)
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 152.4872 - class_out_accuracy: 0.8883 - class_out_loss: 0.2888 - loss: 152.8606
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 878ms/step - box_out_loss: 151.7803 - class_out_accuracy: 0.8863 - class_out_loss: 0.2914 - loss: 152.1555 - val_box_out_loss: 4334.8311 - val_class_out_accuracy: 0.5161 - val_class_out_loss: 0.7927 - val_loss: 893.9428 - learning_rate: 0.0018
# tf.Tensor(0.0016565686, shape=(), dtype=float32)
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 116.1968 - class_out_accuracy: 0.8760 - class_out_loss: 0.3327 - loss: 116.5605
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 899ms/step - box_out_loss: 116.2353 - class_out_accuracy: 0.8750 - class_out_loss: 0.3337 - loss: 116.6006 - val_box_out_loss: 4348.9346 - val_class_out_accuracy: 0.4156 - val_class_out_loss: 0.9275 - val_loss: 881.5302 - learning_rate: 0.0017
# tf.Tensor(0.0014989253, shape=(), dtype=float32)
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 81.9751 - class_out_accuracy: 0.8774 - class_out_loss: 0.3439 - loss: 82.3418
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 894ms/step - box_out_loss: 82.4529 - class_out_accuracy: 0.8774 - class_out_loss: 0.3436 - loss: 82.8198 - val_box_out_loss: 4393.3525 - val_class_out_accuracy: 0.3928 - val_class_out_loss: 1.0676 - val_loss: 897.8630 - learning_rate: 0.0015
# tf.Tensor(0.0013562837, shape=(), dtype=float32)
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 107.8755 - class_out_accuracy: 0.8840 - class_out_loss: 0.2997 - loss: 108.1871
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 890ms/step - box_out_loss: 107.4487 - class_out_accuracy: 0.8840 - class_out_loss: 0.3003 - loss: 107.7617 - val_box_out_loss: 4450.5425 - val_class_out_accuracy: 0.3947 - val_class_out_loss: 1.1620 - val_loss: 903.7681 - learning_rate: 0.0014
# tf.Tensor(0.0012272162, shape=(), dtype=float32)
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 89.0766 - class_out_accuracy: 0.8648 - class_out_loss: 0.3063 - loss: 89.4382
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 899ms/step - box_out_loss: 88.9381 - class_out_accuracy: 0.8647 - class_out_loss: 0.3069 - loss: 89.2998 - val_box_out_loss: 4429.5703 - val_class_out_accuracy: 0.4725 - val_class_out_loss: 0.8962 - val_loss: 901.1620 - learning_rate: 0.0012
# tf.Tensor(0.0011104312, shape=(), dtype=float32)
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 93.8345 - class_out_accuracy: 0.9180 - class_out_loss: 0.2574 - loss: 94.1001
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 887ms/step - box_out_loss: 93.4946 - class_out_accuracy: 0.9170 - class_out_loss: 0.2587 - loss: 93.7622 - val_box_out_loss: 4589.5698 - val_class_out_accuracy: 0.6053 - val_class_out_loss: 0.7806 - val_loss: 942.3784 - learning_rate: 0.0011
# tf.Tensor(0.0010047597, shape=(), dtype=float32)
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 62.1770 - class_out_accuracy: 0.9311 - class_out_loss: 0.2360 - loss: 62.4792
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 31s 892ms/step - box_out_loss: 62.4500 - class_out_accuracy: 0.9298 - class_out_loss: 0.2376 - loss: 62.7528 - val_box_out_loss: 4602.1333 - val_class_out_accuracy: 0.5123 - val_class_out_loss: 0.8131 - val_loss: 917.5141 - learning_rate: 0.0010
# tf.Tensor(0.0009091442, shape=(), dtype=float32)
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 54.3638 - class_out_accuracy: 0.8725 - class_out_loss: 0.3214 - loss: 54.7006
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 899ms/step - box_out_loss: 54.6234 - class_out_accuracy: 0.8733 - class_out_loss: 0.3194 - loss: 54.9585 - val_box_out_loss: 4381.2661 - val_class_out_accuracy: 0.3719 - val_class_out_loss: 1.3890 - val_loss: 883.2874 - learning_rate: 9.0914e-04
# tf.Tensor(0.0008226277, shape=(), dtype=float32)
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 57.5816 - class_out_accuracy: 0.8953 - class_out_loss: 0.2438 - loss: 57.8648
# Class: y_true= [1]  | y_pred= 1
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 32s 899ms/step - box_out_loss: 57.6627 - class_out_accuracy: 0.8955 - class_out_loss: 0.2440 - loss: 57.9458 - val_box_out_loss: 4426.0254 - val_class_out_accuracy: 0.4516 - val_class_out_loss: 0.9783 - val_loss: 901.6345 - learning_rate: 8.2263e-04

# %%
# Accuracy & Loss Visualization

#  Overall Loss
train_overall_loss = history.history['loss']
val_overall_loss = history.history['val_loss']

# Classification Accuracy
train_classification_acc = history.history['class_out_accuracy']
val_classification_acc = history.history['val_class_out_accuracy']

# Classification Loss
train_classification_loss = history.history['class_out_loss']
val_classification_loss = history.history['val_class_out_loss']

# Bounding Box Loss
train_bbox_loss = history.history['box_out_loss']
val_bbox_loss = history.history['val_box_out_loss']

epochs = range(1, len(history.history['loss'])+1)

f, ax = plt.subplots(nrows=2,ncols=2,figsize=(18,15))
    
ax[0,0].plot(epochs, train_overall_loss,  marker='o', label='Training')
ax[0,0].plot(epochs, val_overall_loss, marker='o', color = 'green', label='Validation')
ax[0,0].set_title('Overall Loss')
ax[0,0].set_xlabel('Epochs')
ax[0,0].set_ylabel('Loss')
ax[0,0].legend(loc='best')
ax[0,0].grid(True)

ax[0,1].plot(epochs, train_bbox_loss, marker='o', label='Training')
ax[0,1].plot(epochs, val_bbox_loss, marker='o', color = 'green', label='Validation')
ax[0,1].set_title('Bounding Box Loss')
ax[0,1].set_xlabel('Epochs')
ax[0,1].set_ylabel('Loss')
ax[0,1].legend(loc='best')
ax[0,1].grid(True)



ax[1,0].plot(epochs, train_classification_acc,  marker='o', label='Training')
ax[1,0].plot(epochs, val_classification_acc, marker='o', color = 'green', label='Validation')
ax[1,0].set_title('Classification Accuracy')
ax[1,0].set_xlabel('Epochs')
ax[1,0].set_ylabel('Accuracy')
ax[1,0].legend(loc='best')
ax[1,0].grid(True)

ax[1,1].plot(epochs, train_classification_loss, marker='o', label='Training')
ax[1,1].plot(epochs, val_classification_loss, marker='o', color = 'green', label='Validation')
ax[1,1].set_title('Classification Loss')
ax[1,1].set_xlabel('Epochs')
ax[1,1].set_ylabel('Loss')
ax[1,1].legend(loc='best')
ax[1,1].grid(True)

plt.show()
f.savefig('LossAndAccuracy.eps', format='eps')
plt.close()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
#model.save("test1 ball detection.h5")
model.save("ball_detection_V2.keras")

# %%
#converter = tf.lite.TFLiteConverter.from_keras_model(model)
#tflite_model = converter.convert()
#open("ball_detection_V2.tflite", "wb").write(tflite_model)

# %%
@keras.saving.register_keras_serializable(package="custom_package", name="custom_mse")
def custom_mse(y_true, y_pred):
    print("mse y_pred: ", y_pred)
    mask = K.not_equal(K.sum(y_true, axis=1), 0.0)
    y_true_custom = y_true[mask]
    y_pred_custom = y_pred[mask]
    print("mse y_pred_custom: ", y_pred_custom)
    mse = tf.keras.losses.MeanSquaredError()
    result = mse(y_true_custom, y_pred_custom) # * 0.3
    print("mse result: ", result)
    return result
new_model = tf.keras.models.load_model("ball_detection_V2.keras")
new_model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 264, 640, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d              │ (None, 129, 317, 64)      │             403 │ image[0][0]                │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 158, 64)       │               0 │ separable_conv2d[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_1            │ (None, 64, 158, 192)      │          13,056 │ max_pooling2d[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 79, 192)       │               0 │ separable_conv2d_1[0][0]   │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_2            │ (None, 32, 79, 16)        │           4,816 │ max_pooling2d_1[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 32, 79, 16)        │              64 │ separable_conv2d_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 32, 79, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_3            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu[0][0]          │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_4            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu_1[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 79, 16)        │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ separable_conv2d_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 39, 16)        │               0 │ leaky_re_lu_2[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_5            │ (None, 16, 39, 32)        │             688 │ max_pooling2d_2[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_6            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_3[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_7            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_4[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 16, 39, 32)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ separable_conv2d_5[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 8, 19, 32)         │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_8            │ (None, 8, 19, 64)         │           2,400 │ max_pooling2d_3[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_8[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_9            │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_6[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_9[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_10           │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_7[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_10[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 8, 19, 64)         │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ separable_conv2d_8[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 4, 9, 64)          │               0 │ leaky_re_lu_8[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_11           │ (None, 4, 9, 128)         │           8,896 │ max_pooling2d_4[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 4, 9, 128)         │             512 │ separable_conv2d_11[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 4, 9, 128)         │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_12           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_9[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_12[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_13           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_10[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_13[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 4, 9, 128)         │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ separable_conv2d_11[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 2, 4, 128)         │               0 │ leaky_re_lu_11[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_14           │ (None, 2, 4, 256)         │          34,176 │ max_pooling2d_5[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_14[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_12 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_15           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_12[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_15[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_13 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_16           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_13[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_16[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 2, 4, 256)         │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ separable_conv2d_14[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_14 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2048)              │               0 │ leaky_re_lu_14[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │         262,272 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 512)               │       1,049,088 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_16 (LeakyReLU)    │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_15 (LeakyReLU)    │ (None, 512)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_out (Dense)             │ (None, 1)                 │             129 │ leaky_re_lu_16[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ box_out (Dense)               │ (None, 3)                 │           1,539 │ leaky_re_lu_15[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,697,831 (17.92 MB)
#  Trainable params: 1,564,951 (5.97 MB)
#  Non-trainable params: 2,976 (11.62 KB)
#  Optimizer params: 3,129,904 (11.94 MB)

# %%
#def representative_dataset():
#    c = 0
#    test_images.reset()
#    for ind in range (len(test_images.filenames)):
#        #data_list = []
#        try:
#            data = test_images[ind]
#        #print(data)
#        #data_list.append(data[0])
#
#            for i in range(BATCH_SIZE):
#                c+=1
#        # now, data_array is the numeric data of whole images
#                data_array = np.asarray(data[i])*255
#                data_array = np.expand_dims(data_array, axis=0)
#        #print(data_array.shape)
#        #data_array=np.squeeze(data_array,axis=0)
#        #print(data_array.shape)
#        
#                yield [np.array(data_array, dtype=np.float32, ndmin=2)]
#        except:
#            print(c)
#            break

#converter = tf.lite.TFLiteConverter.from_keras_model(new_model)
#converter.optimizations = [tf.lite.Optimize.DEFAULT]
#converter.experimental_new_quantizer = True
#converter.representative_dataset = representative_dataset
#converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
#converter.inference_input_type = tf.uint8
#converter.inference_output_type = tf.uint8
#tflite_model = converter.convert()
#open("ball_detection_uint8.tflite", "wb").write(tflite_model)

# %%
#interpreter = tf.lite.Interpreter(model_path='ball_detection_uint8.tflite')
#interpreter.allocate_tensors()
#input_details = interpreter.get_input_details()
#output_details = interpreter.get_output_details()
#input_data = image = np.expand_dims(np.asarray(Image.open("./images/valid/frame598.jpg")), axis=0)
#interpreter.set_tensor(input_details[0]['index'], input_data)
#interpreter.invoke()
#output_data = interpreter.get_tensor(output_details[0]['index'])
#print(output_data)
#output_data = interpreter.get_tensor(output_details[1]['index'])
#print(output_data)

# %%
valid_dataset = pd.read_csv('./images/valid/dataset.csv')
#print(valid_dataset)
def visualize_evaluation(model, name):    
    # Get image
    im = Image.open("./images/valid/"+name)
    image = np.expand_dims(np.asarray(im)/255, axis=0)
    #image = np.expand_dims(np.asarray(im)/255, axis=0)
    print(image.shape)
    #print(image)
    
    # Set y_true & y_pred for class & bounding box
    print(valid_dataset.loc[valid_dataset['path']==name]['x'], valid_dataset.loc[valid_dataset['path']==name]['y'], valid_dataset.loc[valid_dataset['path']==name]['w'])
    yt_box = np.array([valid_dataset.loc[valid_dataset['path']==name]['x'], valid_dataset.loc[valid_dataset['path']==name]['y'], valid_dataset.loc[valid_dataset['path']==name]['w']])
    yt_class = np.array(valid_dataset.loc[valid_dataset['path']==name]['ball_exists'])
    
    yp_class, yp_box = model.predict(image)
    print(yp_class, yp_box)

    camera_fov = 120
    angle = (yp_box[0][0]+yp_box[0][2]/2)/640 *camera_fov - camera_fov/2
    print("Ball Angle", angle)

    # Plot bounding box on image & show it
    image_plotted = plot_bbox(image[0], yt_box, yp_box[0], norm=True) #True?
    plt.imshow(image_plotted)
    plt.axis('off')
    
    # Print y_true class & y_pred class
    print("Class: y_true=", yt_class, " | y_pred=", int(yp_class[0][0] >= 0.5))
    plt.show()

# %%
visualize_evaluation(new_model, "frame299.jpg")
# Out:
# (1, 264, 640, 3)
# 1009    0
# Name: x, dtype: int64 1009    0
# Name: y, dtype: int64 1009    0
# Name: w, dtype: int64
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# [[0.8273439]] [[171.33289  52.26348 187.12698]]
# Ball Angle -10.331932
# Class: y_true= [0]  | y_pred= 1

# %%
def visu_tets(sample_index):
    data = custom_test_gen
    image = np.array([data[0][0][sample_index]])
    yt_box = np.array([custom_test_gen[0][1]['box_out'][sample_index]])
    yt_class = np.array([custom_test_gen[0][1]['class_out'][sample_index]])
    yp_class, yp_box = model.predict(image)
    print(image.shape)
    print(image)
    print(image[0].shape)
    image_plotted = plot_bbox(image[0], yt_box[0], yp_box[0], norm=True) 
    plt.imshow(image_plotted)
    plt.axis('off')
    plt.show()

# %%
visu_tets(0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# (1, 264, 640, 3)
# [[[[0.29803923 0.32156864 0.3137255 ]
#    [0.29803923 0.32156864 0.3137255 ]
#    [0.2901961  0.3137255  0.30588236]
#    ...
#    [0.24705884 0.29803923 0.19607845]
#    [0.25490198 0.3019608  0.21568629]
#    [0.25882354 0.30588236 0.227451  ]]
#
#   [[0.29803923 0.32156864 0.3137255 ]
#    [0.29411766 0.31764707 0.30980393]
#    [0.2901961  0.3137255  0.30588236]
#    ...
#    [0.24705884 0.29803923 0.19607845]
#    [0.25490198 0.3019608  0.21568629]
#    [0.25882354 0.30588236 0.227451  ]]
#
#   [[0.29803923 0.32156864 0.3137255 ]
#    [0.29411766 0.31764707 0.30980393]
#    [0.2901961  0.3137255  0.30588236]
#    ...
#    [0.2509804  0.3019608  0.20000002]
#    [0.25490198 0.3019608  0.21568629]
#    [0.2627451  0.30980393 0.23137257]]
#
#   ...
#
#   [[0.3137255  0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    ...
#    [0.42352945 0.48627454 0.48627454]
#    [0.41960788 0.48235297 0.48235297]
#    [0.4156863  0.4784314  0.4784314 ]]
#
#   [[0.3137255  0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    ...
#    [0.42352945 0.48627454 0.48627454]
#    [0.41960788 0.48235297 0.48235297]
#    [0.4156863  0.4784314  0.4784314 ]]
#
#   [[0.3137255  0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    [0.30588236 0.32156864 0.31764707]
#    ...
#    [0.42352945 0.48627454 0.48627454]
#    [0.4156863  0.4784314  0.4784314 ]
#    [0.4156863  0.4784314  0.4784314 ]]]]
# (264, 640, 3)
