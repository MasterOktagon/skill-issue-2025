# %%
import cv2
import os

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from pathlib import Path
from PIL import Image, ImageDraw
from tensorflow.keras import backend as K
#from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Add, Conv2D, SeparableConv2D
from tensorflow.keras.layers import BatchNormalization, AveragePooling2D
from tensorflow.keras.layers import LeakyReLU, MaxPooling2D, Flatten
from tensorflow.keras.models import Model

# %%
IMG_HEIGHT = 264
IMG_WIDTH = 640
X_FACTOR = 1
Y_FACTOR = 1
BATCH_SIZE = 128
EPOCHS = 30    # maybe mehr?
learning_rate = 0.003
train_dataset_path = './images/train/'
test_dataset_path = './images/test/'

# %%
# Function to read images names and store them in a DataFrame
def grabPaths(filepath):
    labels = [str(filepath[i]).split("/")[-1] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='path').astype(str)
    
    # Concatenate filepaths and labels

    # Shuffle the DataFrame and reset index
    df = pd.DataFrame(filepath)
    
    return df

# Function to scale boxes coordinates (bacuase images are resized)
def resize_boxes(boxes):
    boxes = np.array(boxes).astype(np.float32)
    boxes = boxes * X_FACTOR
    return (np.rint(boxes)).astype(int)


# Function to draw bounding box given an image & coordinates
def plot_bbox(image, yt_box, yp_box=None, norm=False):
    # If image is normalized (/255.) reconstruct (inverse) the operation
    if norm:
        image = image * 255.
        image = image.astype("uint8")
    
    # Convert image to array if not converted
    try:
        pil_img = Image.fromarray(image)
    except:
        pil_img = Image.fromarray(image.astype('uint8'))
        
    draw_img = ImageDraw.Draw(pil_img)
    
    x1, y1, w = yt_box
    h = w
    x2, y2 = x1+w, y1+h
    draw_img.rectangle((x1, y1, x2, y2), outline='green')
    
    # If y_pred box is given, draw it
    if yp_box is not None:
        x1, y1, w = yp_box
        h = w
        x2, y2 = x1+w, y1+h
        draw_img.rectangle((x1, y1, x2, y2), outline='red')
    return pil_img


# Function to build convolutionl block
def convblock(previous_layer, n_filters, filter_windows=(3,3,3), padding='same', pool=None):
    # [DepthwiseConv -> BatchNorm -> LeakyReLU] x3 + Residual connection -> Pooling (optional)

    x = SeparableConv2D(n_filters[0], filter_windows[0], padding=padding)(previous_layer)
    x_short = x
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[1], filter_windows[1], padding=padding)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[2], filter_windows[2], padding=padding)(x)
    x = BatchNormalization()(x)
    x = Add()([x, x_short])
    x = LeakyReLU()(x)
    
    if pool == 'max':
        x = MaxPooling2D(pool_size=(2,2))(x)
    elif pool == 'avg':
        x = AveragePooling2D(pool_size=(2,2))(x)
    
    return x

# Function to show samples
def visualize_samples(datagen, row_col_len=4, figsize=None):
    figsize = figsize or np.array((row_col_len, row_col_len)) * 4
    fig, ax = plt.subplots(row_col_len*5, row_col_len, figsize=figsize)
    for i in range(row_col_len*5):
        for j in range(row_col_len):
            batch_index = np.random.randint(0, BATCH_SIZE/2)
            output_classes = np.array(datagen[batch_index][1]['class_out'])
            classes_true = np.where(output_classes == 1)[0]
            sample_index = classes_true[np.random.randint(0, classes_true.shape[0])]
            image = datagen[batch_index][0][sample_index]
            box = datagen[batch_index][1]['box_out'][sample_index]
            plotted_box = plot_bbox(image, box, norm=True)
            ax[i,j].imshow(plotted_box)
            ax[i,j].set_axis_off()
            #ax[i,j].title.set_text(str(batch_index*BATCH_SIZE+sample_index))
    plt.show()
    


# Function to make a prediction during training
def visualize_prediction(model, data):    
    # Select a sample where an object exists
    output_classes = np.array(custom_test_gen[0][1]['class_out'])
    sample_index = np.where(output_classes == 1)[0]
    sample_index = sample_index[0] if sample_index[0] else 0 
    
    # Get image
    image = np.array([data[0][0][sample_index]])
    
    # Set y_true & y_pred for class & bounding box
    yt_box = np.array([custom_test_gen[0][1]['box_out'][sample_index]])
    yt_class = np.array([custom_test_gen[0][1]['class_out'][sample_index]])
    yp_class, yp_box = model.predict(image)

    # Plot bounding box on image & show it
    image_plotted = plot_bbox(image[0], yt_box[0], yp_box[0], norm=True) 
    plt.imshow(image_plotted)
    plt.axis('off')
    
    # Print y_true class & y_pred class
    print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
    plt.show()


# Function to reduce learning rate during training        
def lr_scheduler(epoch, lr):
    if epoch > 10:
        lr = lr * tf.math.exp(-0.15)
        print(lr)
    return float(lr)

# Function to calculate MSE Loss function
# for samples where object exists
@tf.keras.utils.register_keras_serializable()
def custom_mse(y_true, y_pred):
    mask = K.not_equal(K.sum(y_true, axis=1), 0.0)
    y_true_custom = y_true[mask]
    y_pred_custom = y_pred[mask]
    mse = tf.keras.losses.MeanSquaredError()
    result = mse(y_true_custom, y_pred_custom) # * 0.3
    return result

# %%
# Read CSV
train_dataset = pd.read_csv('./images/train/dataset.csv')
train_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']
test_dataset = pd.read_csv('./images/test/dataset.csv')
test_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']


# List directories of files
train_image_dir_hand = Path('./images/train')
train_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))
test_image_dir_hand = Path('./images/test')
test_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))

# Create dataframe of {paths, labels}
train_df_hand = grabPaths(train_filepaths_hand)
test_df_hand = grabPaths(test_filepaths_hand)

train_dataset['path'] = "./images/train/" + train_dataset['path']
test_dataset['path'] = "./images/test/" + test_dataset['path']


# Resize boxes, keep zeros if no object exists
train_dataset.iloc[:,2:] = resize_boxes(train_dataset.iloc[:,2:])
test_dataset.iloc[:,2:] = resize_boxes(test_dataset.iloc[:,2:])

# %%
ax = sns.countplot(x='ball_exists', data=train_dataset)
ax.set(xlabel='Object exists in image', ylabel='No. of Image')
# Out:
# [Text(0.5, 0, 'Object exists in image'), Text(0, 0.5, 'No. of Image')]

# %%
# balance dataset (undersampling)
# balls = dataset[dataset['ball_exists'] == 1]
# noballs = dataset[dataset['ball_exists'] == 0]
# balls = balls.sample(frac=0.75).reset_index(drop=True)

# # merge balanced classes & shuffle
# train_df = pd.concat((balls, noballs)).sample(frac=1.).reset_index(drop=True)

# train_df, test_df = train_test_split(train_df, test_size=0.2)

# print(f"No. Training Samples: {train_df.shape[0]}\nNo. Validation Samples: {test_df.shape[0]}")

# %%
# Create custom Generator for multiple output models
class MultiOutputGen(tf.keras.utils.Sequence):
    def __init__(self, input_gen, output_gen):
        self.inpgen = input_gen
        self.outgen = output_gen
#         assert len(input_gen) == len(output_gen)

    def __len__(self):
        return len(self.inpgen)

    def __getitem__(self, i):
        images = self.inpgen[i]
        start = i * images.shape[0]
        end = (i+1) * images.shape[0]
        classes_num = self.outgen.iloc[start:end,0].values
        x = self.outgen.iloc[start:end,1]
        y = self.outgen.iloc[start:end,2]
        w = self.outgen.iloc[start:end,3]
#         h = self.outgen.iloc[start:end,4]
        return images, {'class_out':classes_num, 'box_out':np.array([x, y, w]).T}

    def on_epoch_end(self):
        self.inpgen.on_epoch_end()
    
# Class to visualize predictions during training
class ConvergenceVisualization(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        global custom_test_gen
        visualize_prediction(self.model, custom_test_gen)

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    brightness_range=(0.8, 1.2),
    rescale = 1./255.,
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255.,
)

train_images = train_generator.flow_from_dataframe(
    dataframe=train_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

# Create multi-output generator
custom_train_gen = MultiOutputGen(train_images, train_dataset.iloc[:,1:])
custom_test_gen = MultiOutputGen(test_images, test_dataset.iloc[:,1:])
# Out:
# Found 8458 validated image filenames.
# Found 637 validated image filenames.

# %%
visualize_samples(custom_train_gen, 2)

# %%
# BEST MODEL

inp = Input(shape=(IMG_HEIGHT,IMG_WIDTH,3), name='image')

X = SeparableConv2D(64, (7,7), strides=2, padding='valid')(inp)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = SeparableConv2D(192, (3,3), strides=1, padding='same')(X)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = convblock(X, [16, 16, 16], pool='max')
X = convblock(X, [32, 32, 32], pool='max')
X = convblock(X, [64, 64, 64], pool='max')
X = convblock(X, [128, 128, 128], pool='max')
X = convblock(X, [256, 256, 256])

X = Flatten()(X)
boxX = Dense(512)(X)
boxX = LeakyReLU()(boxX)

classX = Dense(128)(X)
classX = LeakyReLU()(classX)

box_out = Dense(3, name='box_out')(boxX)
class_out = Dense(1, name='class_out', activation='sigmoid')(classX)


model = Model(inp, [class_out, box_out])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 264, 640, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d              │ (None, 129, 317, 64)      │             403 │ image[0][0]                │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 158, 64)       │               0 │ separable_conv2d[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_1            │ (None, 64, 158, 192)      │          13,056 │ max_pooling2d[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 79, 192)       │               0 │ separable_conv2d_1[0][0]   │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_2            │ (None, 32, 79, 16)        │           4,816 │ max_pooling2d_1[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 32, 79, 16)        │              64 │ separable_conv2d_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 32, 79, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_3            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu[0][0]          │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_4            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu_1[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 79, 16)        │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ separable_conv2d_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 39, 16)        │               0 │ leaky_re_lu_2[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_5            │ (None, 16, 39, 32)        │             688 │ max_pooling2d_2[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_6            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_3[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_7            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_4[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 16, 39, 32)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ separable_conv2d_5[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 8, 19, 32)         │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_8            │ (None, 8, 19, 64)         │           2,400 │ max_pooling2d_3[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_8[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_9            │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_6[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_9[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_10           │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_7[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_10[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 8, 19, 64)         │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ separable_conv2d_8[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 4, 9, 64)          │               0 │ leaky_re_lu_8[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_11           │ (None, 4, 9, 128)         │           8,896 │ max_pooling2d_4[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 4, 9, 128)         │             512 │ separable_conv2d_11[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 4, 9, 128)         │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_12           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_9[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_12[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_13           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_10[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_13[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 4, 9, 128)         │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ separable_conv2d_11[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 2, 4, 128)         │               0 │ leaky_re_lu_11[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_14           │ (None, 2, 4, 256)         │          34,176 │ max_pooling2d_5[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_14[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_12 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_15           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_12[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_15[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_13 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_16           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_13[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_16[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 2, 4, 256)         │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ separable_conv2d_14[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_14 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2048)              │               0 │ leaky_re_lu_14[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │         262,272 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 512)               │       1,049,088 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_16 (LeakyReLU)    │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_15 (LeakyReLU)    │ (None, 512)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_out (Dense)             │ (None, 1)                 │             129 │ leaky_re_lu_16[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ box_out (Dense)               │ (None, 3)                 │           1,539 │ leaky_re_lu_15[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,567,927 (5.98 MB)
#  Trainable params: 1,564,951 (5.97 MB)
#  Non-trainable params: 2,976 (11.62 KB)

# %%
adam = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model.compile(
    loss={
        "box_out":custom_mse,
        'class_out':'binary_crossentropy'
    },
    metrics={
        'class_out':'accuracy'
    },
    optimizer=adam
)

# %%
history = model.fit(
    custom_train_gen,
    epochs=EPOCHS,
    validation_data=custom_test_gen,
    callbacks=[
        tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
        ConvergenceVisualization()
    ]
)
# Out:
# C:\Users\Salkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step- box_out_loss: 13176.8955 - class_out_accuracy: 0.8738 - class_out_loss: 3.2011 - loss: 13134.9229
# Class: y_true= [1]  | y_pred= 1
# C:\Users\Salkin\AppData\Local\Temp\ipykernel_28660\453017214.py:117: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - box_out_loss: 13113.2744 - class_out_accuracy: 0.8743 - class_out_loss: 3.1952 - loss: 13070.6221 - val_box_out_loss: 15126.9502 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.1545 - val_loss: 15199.3457 - learning_rate: 0.0030
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 6060.5957 - class_out_accuracy: 0.9231 - class_out_loss: 0.4400 - loss: 5935.8081
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 868ms/step - box_out_loss: 6058.5771 - class_out_accuracy: 0.9231 - class_out_loss: 0.4401 - loss: 5934.0703 - val_box_out_loss: 13276.3691 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.7749 - val_loss: 13340.6660 - learning_rate: 0.0030
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 4814.8550 - class_out_accuracy: 0.8200 - class_out_loss: 1.1721 - loss: 4742.6050
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 59s 875ms/step - box_out_loss: 4819.6436 - class_out_accuracy: 0.8215 - class_out_loss: 1.1617 - loss: 4746.5498 - val_box_out_loss: 11547.0498 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 3.8887 - val_loss: 11605.3096 - learning_rate: 0.0030
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 4542.6982 - class_out_accuracy: 0.9855 - class_out_loss: 0.2224 - loss: 4521.9844
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 867ms/step - box_out_loss: 4540.8574 - class_out_accuracy: 0.9846 - class_out_loss: 0.2321 - loss: 4518.3101 - val_box_out_loss: 9773.3926 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 2.2643 - val_loss: 9821.6787 - learning_rate: 0.0030
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 4251.5571 - class_out_accuracy: 0.9383 - class_out_loss: 1.0121 - loss: 4043.8813
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 59s 872ms/step - box_out_loss: 4254.7773 - class_out_accuracy: 0.9382 - class_out_loss: 1.0098 - loss: 4047.1787 - val_box_out_loss: 8295.7998 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 0.9016 - val_loss: 8335.7695 - learning_rate: 0.0030
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 3531.1956 - class_out_accuracy: 0.9866 - class_out_loss: 0.0744 - loss: 3429.4202
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 59s 880ms/step - box_out_loss: 3528.8477 - class_out_accuracy: 0.9860 - class_out_loss: 0.0769 - loss: 3426.4060 - val_box_out_loss: 6005.5405 - val_class_out_accuracy: 0.5008 - val_class_out_loss: 0.6882 - val_loss: 6034.5122 - learning_rate: 0.0030
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 2608.2715 - class_out_accuracy: 0.9331 - class_out_loss: 0.3501 - loss: 2498.8638
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 859ms/step - box_out_loss: 2609.4724 - class_out_accuracy: 0.9334 - class_out_loss: 0.3493 - loss: 2499.7205 - val_box_out_loss: 3599.7961 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.4068 - val_loss: 3618.1531 - learning_rate: 0.0030
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 2346.2842 - class_out_accuracy: 0.9194 - class_out_loss: 0.3454 - loss: 2272.1892
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 57s 853ms/step - box_out_loss: 2346.9170 - class_out_accuracy: 0.9195 - class_out_loss: 0.3467 - loss: 2271.4216 - val_box_out_loss: 2311.9192 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.5334 - val_loss: 2324.3364 - learning_rate: 0.0030
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 1628.5084 - class_out_accuracy: 0.9818 - class_out_loss: 0.1195 - loss: 1618.1583
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 862ms/step - box_out_loss: 1631.1523 - class_out_accuracy: 0.9814 - class_out_loss: 0.1215 - loss: 1618.4399 - val_box_out_loss: 2298.4919 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.4901 - val_loss: 2310.8030 - learning_rate: 0.0030
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 1946.3792 - class_out_accuracy: 0.9614 - class_out_loss: 0.2061 - loss: 1795.2943
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 57s 852ms/step - box_out_loss: 1946.2345 - class_out_accuracy: 0.9613 - class_out_loss: 0.2068 - loss: 1794.9894 - val_box_out_loss: 1558.7347 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 3.5322 - val_loss: 1569.5973 - learning_rate: 0.0030
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 1937.7933 - class_out_accuracy: 0.9634 - class_out_loss: 0.1763 - loss: 1540.5891
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 860ms/step - box_out_loss: 1933.3538 - class_out_accuracy: 0.9632 - class_out_loss: 0.1770 - loss: 1539.6334 - val_box_out_loss: 1936.9133 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 2.1879 - val_loss: 1948.2173 - learning_rate: 0.0030
# tf.Tensor(0.002582124, shape=(), dtype=float32)
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/steptep - box_out_loss: 1228.3831 - class_out_accuracy: 0.9569 - class_out_loss: 0.2243 - loss: 1094.2129
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 57s 853ms/step - box_out_loss: 1230.1089 - class_out_accuracy: 0.9569 - class_out_loss: 0.2243 - loss: 1095.6357 - val_box_out_loss: 1254.3901 - val_class_out_accuracy: 0.3736 - val_class_out_loss: 1.1342 - val_loss: 1261.4287 - learning_rate: 0.0026
# tf.Tensor(0.0022224546, shape=(), dtype=float32)
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 1031.6514 - class_out_accuracy: 0.9618 - class_out_loss: 0.1970 - loss: 984.2632
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 857ms/step - box_out_loss: 1036.2223 - class_out_accuracy: 0.9617 - class_out_loss: 0.1978 - loss: 986.5443 - val_box_out_loss: 1855.8855 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 2.1338 - val_loss: 1866.7533 - learning_rate: 0.0022
# tf.Tensor(0.0019128845, shape=(), dtype=float32)
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 1387.4358 - class_out_accuracy: 0.9898 - class_out_loss: 0.0703 - loss: 1299.9236
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 859ms/step - box_out_loss: 1385.4930 - class_out_accuracy: 0.9893 - class_out_loss: 0.0722 - loss: 1296.8512 - val_box_out_loss: 1239.7826 - val_class_out_accuracy: 0.4427 - val_class_out_loss: 0.8839 - val_loss: 1246.5033 - learning_rate: 0.0019
# tf.Tensor(0.001646435, shape=(), dtype=float32)
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 915.3481 - class_out_accuracy: 0.9601 - class_out_loss: 0.2535 - loss: 770.5687
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 868ms/step - box_out_loss: 914.1315 - class_out_accuracy: 0.9600 - class_out_loss: 0.2533 - loss: 769.7576 - val_box_out_loss: 1104.6083 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 2.6678 - val_loss: 1112.4712 - learning_rate: 0.0016
# tf.Tensor(0.0014170997, shape=(), dtype=float32)
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 1193.6913 - class_out_accuracy: 0.9815 - class_out_loss: 0.0900 - loss: 686.4442
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 57s 854ms/step - box_out_loss: 1188.8232 - class_out_accuracy: 0.9810 - class_out_loss: 0.0916 - loss: 685.4156 - val_box_out_loss: 1150.2966 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.4775 - val_loss: 1157.1874 - learning_rate: 0.0014
# tf.Tensor(0.001219709, shape=(), dtype=float32)
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 584.8935 - class_out_accuracy: 0.9459 - class_out_loss: 0.1923 - loss: 446.9861
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 860ms/step - box_out_loss: 585.4808 - class_out_accuracy: 0.9460 - class_out_loss: 0.1919 - loss: 447.0478 - val_box_out_loss: 1081.3865 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 2.0736 - val_loss: 1088.5468 - learning_rate: 0.0012
# tf.Tensor(0.0010498133, shape=(), dtype=float32)
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 468.0923 - class_out_accuracy: 0.9810 - class_out_loss: 0.0834 - loss: 369.4420
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 57s 852ms/step - box_out_loss: 469.1147 - class_out_accuracy: 0.9806 - class_out_loss: 0.0848 - loss: 369.5558 - val_box_out_loss: 1315.0476 - val_class_out_accuracy: 0.3830 - val_class_out_loss: 1.1147 - val_loss: 1322.3529 - learning_rate: 0.0010
# tf.Tensor(0.0009035827, shape=(), dtype=float32)
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 320.9464 - class_out_accuracy: 0.9764 - class_out_loss: 0.1277 - loss: 311.0500
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 856ms/step - box_out_loss: 323.3599 - class_out_accuracy: 0.9761 - class_out_loss: 0.1286 - loss: 311.1988 - val_box_out_loss: 1504.4988 - val_class_out_accuracy: 0.3987 - val_class_out_loss: 1.0972 - val_loss: 1512.6788 - learning_rate: 9.0358e-04
# tf.Tensor(0.0007777209, shape=(), dtype=float32)
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 307.3076 - class_out_accuracy: 0.9506 - class_out_loss: 0.1802 - loss: 299.6934
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 57s 853ms/step - box_out_loss: 308.4542 - class_out_accuracy: 0.9506 - class_out_loss: 0.1801 - loss: 299.7228 - val_box_out_loss: 1513.1105 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.8954 - val_loss: 1522.1267 - learning_rate: 7.7772e-04
# tf.Tensor(0.0006693906, shape=(), dtype=float32)
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/steptep - box_out_loss: 398.4066 - class_out_accuracy: 0.9600 - class_out_loss: 0.1536 - loss: 343.6480
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 60s 892ms/step - box_out_loss: 399.9558 - class_out_accuracy: 0.9599 - class_out_loss: 0.1539 - loss: 343.5627 - val_box_out_loss: 1203.1121 - val_class_out_accuracy: 0.3721 - val_class_out_loss: 1.7019 - val_loss: 1210.4756 - learning_rate: 6.6939e-04
# tf.Tensor(0.00057614985, shape=(), dtype=float32)
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 343.8825 - class_out_accuracy: 0.9638 - class_out_loss: 0.1397 - loss: 300.5382
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 854ms/step - box_out_loss: 345.2888 - class_out_accuracy: 0.9636 - class_out_loss: 0.1401 - loss: 300.5231 - val_box_out_loss: 1151.2532 - val_class_out_accuracy: 0.3830 - val_class_out_loss: 1.4850 - val_loss: 1158.1558 - learning_rate: 5.7615e-04
# tf.Tensor(0.0004958968, shape=(), dtype=float32)
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 288.1351 - class_out_accuracy: 0.9650 - class_out_loss: 0.1352 - loss: 263.3824
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 57s 852ms/step - box_out_loss: 289.5741 - class_out_accuracy: 0.9648 - class_out_loss: 0.1357 - loss: 263.4785 - val_box_out_loss: 1313.2650 - val_class_out_accuracy: 0.3815 - val_class_out_loss: 1.4023 - val_loss: 1320.8483 - learning_rate: 4.9590e-04
# tf.Tensor(0.00042682234, shape=(), dtype=float32)
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 296.3165 - class_out_accuracy: 0.9450 - class_out_loss: 0.1907 - loss: 279.7775
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 858ms/step - box_out_loss: 297.6122 - class_out_accuracy: 0.9451 - class_out_loss: 0.1904 - loss: 279.5999 - val_box_out_loss: 1270.5179 - val_class_out_accuracy: 0.3878 - val_class_out_loss: 1.4698 - val_loss: 1277.9678 - learning_rate: 4.2682e-04
# tf.Tensor(0.00036736942, shape=(), dtype=float32)
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 229.2406 - class_out_accuracy: 0.9374 - class_out_loss: 0.1991 - loss: 228.8845
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 856ms/step - box_out_loss: 229.7505 - class_out_accuracy: 0.9377 - class_out_loss: 0.1985 - loss: 228.8551 - val_box_out_loss: 1156.2915 - val_class_out_accuracy: 0.3987 - val_class_out_loss: 1.3561 - val_loss: 1163.0897 - learning_rate: 3.6737e-04
# tf.Tensor(0.00031619778, shape=(), dtype=float32)
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 216.2955 - class_out_accuracy: 0.9718 - class_out_loss: 0.1115 - loss: 207.9549
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 856ms/step - box_out_loss: 216.6720 - class_out_accuracy: 0.9716 - class_out_loss: 0.1122 - loss: 208.0807 - val_box_out_loss: 1262.4554 - val_class_out_accuracy: 0.3987 - val_class_out_loss: 1.3107 - val_loss: 1269.7083 - learning_rate: 3.1620e-04
# tf.Tensor(0.00027215396, shape=(), dtype=float32)
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/steptep - box_out_loss: 231.2707 - class_out_accuracy: 0.9389 - class_out_loss: 0.1976 - loss: 198.8769
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 857ms/step - box_out_loss: 231.1978 - class_out_accuracy: 0.9392 - class_out_loss: 0.1970 - loss: 198.8952 - val_box_out_loss: 1247.3975 - val_class_out_accuracy: 0.4019 - val_class_out_loss: 1.3609 - val_loss: 1254.6293 - learning_rate: 2.7215e-04
# tf.Tensor(0.00023424509, shape=(), dtype=float32)
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 337.3749 - class_out_accuracy: 0.9238 - class_out_loss: 0.2175 - loss: 200.9351
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 57s 855ms/step - box_out_loss: 335.7607 - class_out_accuracy: 0.9243 - class_out_loss: 0.2167 - loss: 200.7902 - val_box_out_loss: 1085.6895 - val_class_out_accuracy: 0.3815 - val_class_out_loss: 1.7067 - val_loss: 1092.5048 - learning_rate: 2.3425e-04
# tf.Tensor(0.00020161663, shape=(), dtype=float32)
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 191.4327 - class_out_accuracy: 0.9817 - class_out_loss: 0.0778 - loss: 178.1126
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 57s 854ms/step - box_out_loss: 191.3894 - class_out_accuracy: 0.9813 - class_out_loss: 0.0789 - loss: 178.0563 - val_box_out_loss: 1109.6429 - val_class_out_accuracy: 0.3893 - val_class_out_loss: 1.4989 - val_loss: 1116.3638 - learning_rate: 2.0162e-04
# tf.Tensor(0.00017353304, shape=(), dtype=float32)
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 187.9048 - class_out_accuracy: 0.9501 - class_out_loss: 0.1631 - loss: 168.1996
# Class: y_true= [1]  | y_pred= 1
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 58s 866ms/step - box_out_loss: 187.7550 - class_out_accuracy: 0.9502 - class_out_loss: 0.1630 - loss: 168.2259 - val_box_out_loss: 1091.4153 - val_class_out_accuracy: 0.4019 - val_class_out_loss: 1.3403 - val_loss: 1097.8920 - learning_rate: 1.7353e-04

# %%
# Accuracy & Loss Visualization

#  Overall Loss
train_overall_loss = history.history['loss']
val_overall_loss = history.history['val_loss']

# Classification Accuracy
train_classification_acc = history.history['class_out_accuracy']
val_classification_acc = history.history['val_class_out_accuracy']

# Classification Loss
train_classification_loss = history.history['class_out_loss']
val_classification_loss = history.history['val_class_out_loss']

# Bounding Box Loss
train_bbox_loss = history.history['box_out_loss']
val_bbox_loss = history.history['val_box_out_loss']

epochs = range(1, len(history.history['loss'])+1)

f, ax = plt.subplots(nrows=2,ncols=2,figsize=(18,15))
    
ax[0,0].plot(epochs, train_overall_loss,  marker='o', label='Training')
ax[0,0].plot(epochs, val_overall_loss, marker='o', color = 'green', label='Validation')
ax[0,0].set_title('Overall Loss')
ax[0,0].set_xlabel('Epochs')
ax[0,0].set_ylabel('Loss')
ax[0,0].legend(loc='best')
ax[0,0].grid(True)

ax[0,1].plot(epochs, train_bbox_loss, marker='o', label='Training')
ax[0,1].plot(epochs, val_bbox_loss, marker='o', color = 'green', label='Validation')
ax[0,1].set_title('Bounding Box Loss')
ax[0,1].set_xlabel('Epochs')
ax[0,1].set_ylabel('Loss')
ax[0,1].legend(loc='best')
ax[0,1].grid(True)



ax[1,0].plot(epochs, train_classification_acc,  marker='o', label='Training')
ax[1,0].plot(epochs, val_classification_acc, marker='o', color = 'green', label='Validation')
ax[1,0].set_title('Classification Accuracy')
ax[1,0].set_xlabel('Epochs')
ax[1,0].set_ylabel('Accuracy')
ax[1,0].legend(loc='best')
ax[1,0].grid(True)

ax[1,1].plot(epochs, train_classification_loss, marker='o', label='Training')
ax[1,1].plot(epochs, val_classification_loss, marker='o', color = 'green', label='Validation')
ax[1,1].set_title('Classification Loss')
ax[1,1].set_xlabel('Epochs')
ax[1,1].set_ylabel('Loss')
ax[1,1].legend(loc='best')
ax[1,1].grid(True)

plt.show()
f.savefig('LossAndAccuracy.eps', format='eps')
plt.close()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
model.save("test1 ball detection.h5")
model.save("ball_detection_V2.keras")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
new_model = tf.keras.models.load_model("ball_detection_V2.keras")
new_model.summary()
# Out:
# C:\Users\Salkin\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 91 variables whereas the saved optimizer has 180 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 264, 640, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d              │ (None, 129, 317, 64)      │             403 │ image[0][0]                │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 64, 158, 64)       │               0 │ separable_conv2d[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_1            │ (None, 64, 158, 192)      │          13,056 │ max_pooling2d[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 32, 79, 192)       │               0 │ separable_conv2d_1[0][0]   │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_2            │ (None, 32, 79, 16)        │           4,816 │ max_pooling2d_1[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 32, 79, 16)        │              64 │ separable_conv2d_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 32, 79, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_3            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu[0][0]          │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_4            │ (None, 32, 79, 16)        │             416 │ leaky_re_lu_1[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 32, 79, 16)        │              64 │ separable_conv2d_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 32, 79, 16)        │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ separable_conv2d_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 32, 79, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 16, 39, 16)        │               0 │ leaky_re_lu_2[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_5            │ (None, 16, 39, 32)        │             688 │ max_pooling2d_2[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_6            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_3[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_7            │ (None, 16, 39, 32)        │           1,344 │ leaky_re_lu_4[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 16, 39, 32)        │             128 │ separable_conv2d_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 16, 39, 32)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ separable_conv2d_5[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 16, 39, 32)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 8, 19, 32)         │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_8            │ (None, 8, 19, 64)         │           2,400 │ max_pooling2d_3[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_8[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_9            │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_6[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_9[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_10           │ (None, 8, 19, 64)         │           4,736 │ leaky_re_lu_7[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 8, 19, 64)         │             256 │ separable_conv2d_10[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 8, 19, 64)         │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ separable_conv2d_8[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 8, 19, 64)         │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 4, 9, 64)          │               0 │ leaky_re_lu_8[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_11           │ (None, 4, 9, 128)         │           8,896 │ max_pooling2d_4[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 4, 9, 128)         │             512 │ separable_conv2d_11[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 4, 9, 128)         │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_12           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_9[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_12[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_13           │ (None, 4, 9, 128)         │          17,664 │ leaky_re_lu_10[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 4, 9, 128)         │             512 │ separable_conv2d_13[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 4, 9, 128)         │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ separable_conv2d_11[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 4, 9, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 2, 4, 128)         │               0 │ leaky_re_lu_11[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_14           │ (None, 2, 4, 256)         │          34,176 │ max_pooling2d_5[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_14[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_12 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_15           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_12[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_15[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_13 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_16           │ (None, 2, 4, 256)         │          68,096 │ leaky_re_lu_13[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 2, 4, 256)         │           1,024 │ separable_conv2d_16[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 2, 4, 256)         │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ separable_conv2d_14[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_14 (LeakyReLU)    │ (None, 2, 4, 256)         │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2048)              │               0 │ leaky_re_lu_14[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │         262,272 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 512)               │       1,049,088 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_16 (LeakyReLU)    │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_15 (LeakyReLU)    │ (None, 512)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_out (Dense)             │ (None, 1)                 │             129 │ leaky_re_lu_16[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ box_out (Dense)               │ (None, 3)                 │           1,539 │ leaky_re_lu_15[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 3,132,880 (11.95 MB)
#  Trainable params: 1,564,951 (5.97 MB)
#  Non-trainable params: 2,976 (11.62 KB)
#  Optimizer params: 1,564,953 (5.97 MB)

# %%
valid_dataset = pd.read_csv('./images/valid/dataset.csv')
#print(valid_dataset)
def visualize_evaluation(model, name):    
    # Get image
    im = Image.open("./images/valid/"+name)
    image = np.asarray(im)
    print(image.shape)
    
    # Set y_true & y_pred for class & bounding box
    print(valid_dataset.loc[valid_dataset['path']==name]['x'], valid_dataset.loc[valid_dataset['path']==name]['y'], valid_dataset.loc[valid_dataset['path']==name]['w'])
    yt_box = np.array([valid_dataset.loc[valid_dataset['path']==name]['x'], valid_dataset.loc[valid_dataset['path']==name]['y'], valid_dataset.loc[valid_dataset['path']==name]['w']])
    yt_class = np.array(valid_dataset.loc[valid_dataset['path']==name]['ball_exists'])
    
    yp_class, yp_box = model.predict(image)

    # Plot bounding box on image & show it
    image_plotted = plot_bbox(image, yt_box, yp_box, norm=False) #True?
    plt.imshow(image_plotted)
    plt.axis('off')
    
    # Print y_true class & y_pred class
    print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
    plt.show()

# %%
visualize_evaluation(model, "frame599.jpg")
# Out:
# (264, 640, 3)
# 1309    0
# Name: x, dtype: int64 1309    0
# Name: y, dtype: int64 1309    0
# Name: w, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 visualize_evaluation(model, "frame599.jpg")
#
# Cell In[44], line 14, in visualize_evaluation(model, name)
#      11 yt_box = np.array([valid_dataset.loc[valid_dataset['path']==name]['x'], valid_dataset.loc[valid_dataset['path']==name]['y'], valid_dataset.loc[valid_dataset['path']==name]['w']])
#      12 yt_class = np.array(valid_dataset.loc[valid_dataset['path']==name]['ball_exists'])
# ---> 14 yp_class, yp_box = model.predict(image)
#      16 # Plot bounding box on image & show it
#      17 image_plotted = plot_bbox(image, yt_box, yp_box, norm=False) #True?
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "functional" is incompatible with the layer: expected shape=(None, 264, 640, 3), found shape=(32, 640, 3)
