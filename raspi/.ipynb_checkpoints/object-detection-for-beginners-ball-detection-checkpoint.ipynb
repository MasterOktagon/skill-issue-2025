# %%
import cv2
import os

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from pathlib import Path
from PIL import Image, ImageDraw
from tensorflow.keras import backend as K
#from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Add, Conv2D, SeparableConv2D
from tensorflow.keras.layers import BatchNormalization, AveragePooling2D
from tensorflow.keras.layers import LeakyReLU, MaxPooling2D, Flatten
from tensorflow.keras.models import Model

# %%
IMG_HEIGHT = 640
IMG_WIDTH = 264
X_FACTOR = IMG_WIDTH / 600 # Scale of resizing images
Y_FACTOR = IMG_HEIGHT / 600 # Scale of resizing images
BATCH_SIZE = 128
EPOCHS = 25
learning_rate = 0.003
train_dataset_path = './images/train/'
test_dataset_path = './images/test/'

# %%
# Function to read images names and store them in a DataFrame
def grabPaths(filepath):
    labels = [str(filepath[i]).split("/")[-1] \
              for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='path').astype(str)
    
    # Concatenate filepaths and labels

    # Shuffle the DataFrame and reset index
    df = pd.DataFrame(filepath)
    
    return df

# Function to scale boxes coordinates (bacuase images are resized)
def resize_boxes(boxes):
    boxes = np.array(boxes).astype(np.float32)
    boxes = boxes * X_FACTOR
    return (np.rint(boxes)).astype(int)


# Function to draw bounding box given an image & coordinates
def plot_bbox(image, yt_box, yp_box=None, norm=False):
    # If image is normalized (/255.) reconstruct (inverse) the operation
    if norm:
        image = image * 255.
        image = image.astype("uint8")
    
    # Convert image to array if not converted
    try:
        pil_img = Image.fromarray(image)
    except:
        pil_img = Image.fromarray(image.astype('uint8'))
        
    draw_img = ImageDraw.Draw(pil_img)
    
    x1, y1, w = yt_box
    h = w
    x2, y2 = x1+w, y1+h
    draw_img.rectangle((x1, y1, x2, y2), outline='green')
    
    # If y_pred box is given, draw it
    if yp_box is not None:
        x1, y1, w = yp_box
        h = w
        x2, y2 = x1+w, y1+h
        draw_img.rectangle((x1, y1, x2, y2), outline='red')
    return pil_img


# Function to build convolutionl block
def convblock(previous_layer, n_filters, filter_windows=(3,3,3), padding='same', pool=None):
    # [DepthwiseConv -> BatchNorm -> LeakyReLU] x3 + Residual connection -> Pooling (optional)

    x = SeparableConv2D(n_filters[0], filter_windows[0], padding=padding)(previous_layer)
    x_short = x
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[1], filter_windows[1], padding=padding)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU()(x)

    x = SeparableConv2D(n_filters[2], filter_windows[2], padding=padding)(x)
    x = BatchNormalization()(x)
    x = Add()([x, x_short])
    x = LeakyReLU()(x)
    
    if pool == 'max':
        x = MaxPooling2D(pool_size=(2,2))(x)
    elif pool == 'avg':
        x = AveragePooling2D(pool_size=(2,2))(x)
    
    return x

# Function to show samples
def visualize_samples(datagen, row_col_len=4, figsize=None):
    figsize = figsize or np.array((row_col_len, row_col_len)) * 4
    fig, ax = plt.subplots(row_col_len, row_col_len, figsize=figsize)
    for i in range(row_col_len):
        for j in range(row_col_len):
            batch_index = np.random.randint(0, BATCH_SIZE/2)
            output_classes = np.array(datagen[batch_index][1]['class_out'])
            classes_true = np.where(output_classes == 1)[0]
            sample_index = classes_true[np.random.randint(0, classes_true.shape[0])]
            image = datagen[batch_index][0][sample_index]
            box = datagen[batch_index][1]['box_out'][sample_index]
            plotted_box = plot_bbox(image, box, norm=True)
            ax[i,j].imshow(plotted_box)
            ax[i,j].set_axis_off()
    plt.show()
    


# Function to make a prediction during training
def visualize_prediction(model, data):    
    # Select a sample where an object exists
    output_classes = np.array(custom_test_gen[0][1]['class_out'])
    sample_index = np.where(output_classes == 1)[0]
    sample_index = sample_index[0] if sample_index[0] else 0 
    
    # Get image
    image = np.array([data[0][0][sample_index]])
    
    # Set y_true & y_pred for class & bounding box
    yt_box = np.array([custom_test_gen[0][1]['box_out'][sample_index]])
    yt_class = np.array([custom_test_gen[0][1]['class_out'][sample_index]])
    yp_class, yp_box = model.predict(image)

    # Plot bounding box on image & show it
    image_plotted = plot_bbox(image[0], yt_box[0], yp_box[0], norm=True) 
    plt.imshow(image_plotted)
    plt.axis('off')
    
    # Print y_true class & y_pred class
    print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
    plt.show()


# Function to reduce learning rate during training        
def lr_scheduler(epoch, lr):
    if epoch > 10:
        lr = lr * tf.math.exp(-0.15)
        print(lr)
    return float(lr)

# Function to calculate MSE Loss function
# for samples where object exists
def custom_mse(y_true, y_pred):
    mask = K.not_equal(K.sum(y_true, axis=1), 0.0)
    y_true_custom = y_true[mask]
    y_pred_custom = y_pred[mask]
    mse = tf.keras.losses.MeanSquaredError()
    result = mse(y_true_custom, y_pred_custom) # * 0.3
    return result

# %%
# Read CSV
train_dataset = pd.read_csv('./images/train/dataset.csv')
train_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']
test_dataset = pd.read_csv('./images/test/dataset.csv')
test_dataset.columns = ['path', 'ball_exists', 'x', 'y', 'w', 'h']


# List directories of files
train_image_dir_hand = Path('./images/train')
train_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))
test_image_dir_hand = Path('./images/test')
test_filepaths_hand = list(train_image_dir_hand.glob(r'**/*.jpg'))

# Create dataframe of {paths, labels}
train_df_hand = grabPaths(train_filepaths_hand)
test_df_hand = grabPaths(test_filepaths_hand)

train_dataset['path'] = "./images/train/" + train_dataset['path']
test_dataset['path'] = "./images/test/" + test_dataset['path']


# Resize boxes, keep zeros if no object exists
train_dataset.iloc[:,2:] = resize_boxes(train_dataset.iloc[:,2:])
test_dataset.iloc[:,2:] = resize_boxes(test_dataset.iloc[:,2:])

# %%
ax = sns.countplot(x='ball_exists', data=train_dataset)
ax.set(xlabel='Object exists in image', ylabel='No. of Image')
# Out:
# [Text(0.5, 0, 'Object exists in image'), Text(0, 0.5, 'No. of Image')]

# %%
# balance dataset (undersampling)
# balls = dataset[dataset['ball_exists'] == 1]
# noballs = dataset[dataset['ball_exists'] == 0]
# balls = balls.sample(frac=0.75).reset_index(drop=True)

# # merge balanced classes & shuffle
# train_df = pd.concat((balls, noballs)).sample(frac=1.).reset_index(drop=True)

# train_df, test_df = train_test_split(train_df, test_size=0.2)

# print(f"No. Training Samples: {train_df.shape[0]}\nNo. Validation Samples: {test_df.shape[0]}")

# %%
# Create custom Generator for multiple output models
class MultiOutputGen(tf.keras.utils.Sequence):
    def __init__(self, input_gen, output_gen):
        self.inpgen = input_gen
        self.outgen = output_gen
#         assert len(input_gen) == len(output_gen)

    def __len__(self):
        return len(self.inpgen)

    def __getitem__(self, i):
        images = self.inpgen[i]
        start = i * images.shape[0]
        end = (i+1) * images.shape[0]
        classes_num = self.outgen.iloc[start:end,0].values
        x = self.outgen.iloc[start:end,1]
        y = self.outgen.iloc[start:end,2]
        w = self.outgen.iloc[start:end,3]
#         h = self.outgen.iloc[start:end,4]
        return images, {'class_out':classes_num, 'box_out':np.array([x, y, w]).T}

    def on_epoch_end(self):
        self.inpgen.on_epoch_end()
    
# Class to visualize predictions during training
class ConvergenceVisualization(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        global custom_test_gen
        visualize_prediction(self.model, custom_test_gen)

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    brightness_range=(0.8, 1.2),
    rescale = 1./255.,
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1./255.,
)

train_images = train_generator.flow_from_dataframe(
    dataframe=train_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

test_images = test_generator.flow_from_dataframe(
    dataframe=test_dataset,
    x_col='path',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    color_mode='rgb',
    class_mode=None,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

# Create multi-output generator
custom_train_gen = MultiOutputGen(train_images, train_dataset.iloc[:,1:])
custom_test_gen = MultiOutputGen(test_images, test_dataset.iloc[:,1:])
# Out:
# Found 8058 validated image filenames.
# Found 237 validated image filenames.

# %%
visualize_samples(custom_train_gen, 2)

# %%
# BEST MODEL

inp = Input(shape=(IMG_HEIGHT,IMG_WIDTH,3), name='image')

X = SeparableConv2D(64, (7,7), strides=2, padding='valid')(inp)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = SeparableConv2D(192, (3,3), strides=1, padding='same')(X)
X = MaxPooling2D(pool_size=(2,2), strides=2)(X)

X = convblock(X, [16, 16, 16], pool='max')
X = convblock(X, [32, 32, 32], pool='max')
X = convblock(X, [64, 64, 64], pool='max')
X = convblock(X, [128, 128, 128], pool='max')
X = convblock(X, [256, 256, 256])

X = Flatten()(X)
boxX = Dense(512)(X)
boxX = LeakyReLU()(boxX)

classX = Dense(128)(X)
classX = LeakyReLU()(classX)

box_out = Dense(3, name='box_out')(boxX)
class_out = Dense(1, name='class_out', activation='sigmoid')(classX)


model = Model(inp, [class_out, box_out])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image (InputLayer)            │ (None, 640, 264, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d              │ (None, 317, 129, 64)      │             403 │ image[0][0]                │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 158, 64, 64)       │               0 │ separable_conv2d[0][0]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_1            │ (None, 158, 64, 192)      │          13,056 │ max_pooling2d[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 79, 32, 192)       │               0 │ separable_conv2d_1[0][0]   │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_2            │ (None, 79, 32, 16)        │           4,816 │ max_pooling2d_1[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization           │ (None, 79, 32, 16)        │              64 │ separable_conv2d_2[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu (LeakyReLU)       │ (None, 79, 32, 16)        │               0 │ batch_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_3            │ (None, 79, 32, 16)        │             416 │ leaky_re_lu[0][0]          │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_1         │ (None, 79, 32, 16)        │              64 │ separable_conv2d_3[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)     │ (None, 79, 32, 16)        │               0 │ batch_normalization_1[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_4            │ (None, 79, 32, 16)        │             416 │ leaky_re_lu_1[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_2         │ (None, 79, 32, 16)        │              64 │ separable_conv2d_4[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 79, 32, 16)        │               0 │ batch_normalization_2[0][… │
# │                               │                           │                 │ separable_conv2d_2[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)     │ (None, 79, 32, 16)        │               0 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 39, 16, 16)        │               0 │ leaky_re_lu_2[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_5            │ (None, 39, 16, 32)        │             688 │ max_pooling2d_2[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_3         │ (None, 39, 16, 32)        │             128 │ separable_conv2d_5[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)     │ (None, 39, 16, 32)        │               0 │ batch_normalization_3[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_6            │ (None, 39, 16, 32)        │           1,344 │ leaky_re_lu_3[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_4         │ (None, 39, 16, 32)        │             128 │ separable_conv2d_6[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)     │ (None, 39, 16, 32)        │               0 │ batch_normalization_4[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_7            │ (None, 39, 16, 32)        │           1,344 │ leaky_re_lu_4[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_5         │ (None, 39, 16, 32)        │             128 │ separable_conv2d_7[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 39, 16, 32)        │               0 │ batch_normalization_5[0][… │
# │                               │                           │                 │ separable_conv2d_5[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)     │ (None, 39, 16, 32)        │               0 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_3               │ (None, 19, 8, 32)         │               0 │ leaky_re_lu_5[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_8            │ (None, 19, 8, 64)         │           2,400 │ max_pooling2d_3[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_6         │ (None, 19, 8, 64)         │             256 │ separable_conv2d_8[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)     │ (None, 19, 8, 64)         │               0 │ batch_normalization_6[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_9            │ (None, 19, 8, 64)         │           4,736 │ leaky_re_lu_6[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_7         │ (None, 19, 8, 64)         │             256 │ separable_conv2d_9[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)     │ (None, 19, 8, 64)         │               0 │ batch_normalization_7[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_10           │ (None, 19, 8, 64)         │           4,736 │ leaky_re_lu_7[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_8         │ (None, 19, 8, 64)         │             256 │ separable_conv2d_10[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 19, 8, 64)         │               0 │ batch_normalization_8[0][… │
# │                               │                           │                 │ separable_conv2d_8[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)     │ (None, 19, 8, 64)         │               0 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 9, 4, 64)          │               0 │ leaky_re_lu_8[0][0]        │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_11           │ (None, 9, 4, 128)         │           8,896 │ max_pooling2d_4[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_9         │ (None, 9, 4, 128)         │             512 │ separable_conv2d_11[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)     │ (None, 9, 4, 128)         │               0 │ batch_normalization_9[0][… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_12           │ (None, 9, 4, 128)         │          17,664 │ leaky_re_lu_9[0][0]        │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_10        │ (None, 9, 4, 128)         │             512 │ separable_conv2d_12[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)    │ (None, 9, 4, 128)         │               0 │ batch_normalization_10[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_13           │ (None, 9, 4, 128)         │          17,664 │ leaky_re_lu_10[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_11        │ (None, 9, 4, 128)         │             512 │ separable_conv2d_13[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 9, 4, 128)         │               0 │ batch_normalization_11[0]… │
# │                               │                           │                 │ separable_conv2d_11[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)    │ (None, 9, 4, 128)         │               0 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 4, 2, 128)         │               0 │ leaky_re_lu_11[0][0]       │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_14           │ (None, 4, 2, 256)         │          34,176 │ max_pooling2d_5[0][0]      │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_12        │ (None, 4, 2, 256)         │           1,024 │ separable_conv2d_14[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_12 (LeakyReLU)    │ (None, 4, 2, 256)         │               0 │ batch_normalization_12[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_15           │ (None, 4, 2, 256)         │          68,096 │ leaky_re_lu_12[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_13        │ (None, 4, 2, 256)         │           1,024 │ separable_conv2d_15[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_13 (LeakyReLU)    │ (None, 4, 2, 256)         │               0 │ batch_normalization_13[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ separable_conv2d_16           │ (None, 4, 2, 256)         │          68,096 │ leaky_re_lu_13[0][0]       │
# │ (SeparableConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_14        │ (None, 4, 2, 256)         │           1,024 │ separable_conv2d_16[0][0]  │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 4, 2, 256)         │               0 │ batch_normalization_14[0]… │
# │                               │                           │                 │ separable_conv2d_14[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_14 (LeakyReLU)    │ (None, 4, 2, 256)         │               0 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 2048)              │               0 │ leaky_re_lu_14[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 128)               │         262,272 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 512)               │       1,049,088 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_16 (LeakyReLU)    │ (None, 128)               │               0 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ leaky_re_lu_15 (LeakyReLU)    │ (None, 512)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_out (Dense)             │ (None, 1)                 │             129 │ leaky_re_lu_16[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ box_out (Dense)               │ (None, 3)                 │           1,539 │ leaky_re_lu_15[0][0]       │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,567,927 (5.98 MB)
#  Trainable params: 1,564,951 (5.97 MB)
#  Non-trainable params: 2,976 (11.62 KB)

# %%
adam = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model.compile(
    loss={
        "box_out":custom_mse,
        'class_out':'binary_crossentropy'
    },
    metrics={
        'class_out':'accuracy'
    },
    optimizer=adam
)

# %%
history = model.fit(
    custom_train_gen,
    epochs=EPOCHS,
    validation_data=custom_test_gen,
    callbacks=[
        tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
        ConvergenceVisualization()
    ]
)
# Out:
# Epoch 1/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - box_out_loss: 243.0141 - class_out_accuracy: 1.0000 - class_out_loss: 8.3990e-08 - loss: 241.6705
# Class: y_true= [1]  | y_pred= 1
# C:\Users\Salkin\AppData\Local\Temp\ipykernel_50512\1157806439.py:116: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Class: y_true=", yt_class, " | y_pred=", int(yp_class >= 0.5))
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - box_out_loss: 243.4527 - class_out_accuracy: 1.0000 - class_out_loss: 8.3272e-08 - loss: 242.1050 - val_box_out_loss: 2129.5588 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 5.2000e-12 - val_loss: 2014.3096 - learning_rate: 0.0030
# Epoch 2/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 182.7316 - class_out_accuracy: 1.0000 - class_out_loss: 9.5768e-08 - loss: 182.4642
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 847ms/step - box_out_loss: 183.2876 - class_out_accuracy: 1.0000 - class_out_loss: 9.5255e-08 - loss: 183.0000 - val_box_out_loss: 2495.7649 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 5.2475e-11 - val_loss: 2373.5012 - learning_rate: 0.0030
# Epoch 3/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/steptep - box_out_loss: 182.4915 - class_out_accuracy: 1.0000 - class_out_loss: 2.1510e-07 - loss: 182.2229
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 856ms/step - box_out_loss: 182.9417 - class_out_accuracy: 1.0000 - class_out_loss: 2.1310e-07 - loss: 182.6528 - val_box_out_loss: 2312.4504 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 6.4008e-10 - val_loss: 2179.5137 - learning_rate: 0.0030
# Epoch 4/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 192.6824 - class_out_accuracy: 1.0000 - class_out_loss: 1.3234e-06 - loss: 192.0071
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 857ms/step - box_out_loss: 193.1318 - class_out_accuracy: 1.0000 - class_out_loss: 1.3117e-06 - loss: 192.4460 - val_box_out_loss: 2249.1338 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 3.4286e-10 - val_loss: 2122.5781 - learning_rate: 0.0030
# Epoch 5/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 173.4804 - class_out_accuracy: 1.0000 - class_out_loss: 1.6363e-08 - loss: 172.8201
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 846ms/step - box_out_loss: 173.7852 - class_out_accuracy: 1.0000 - class_out_loss: 1.6486e-08 - loss: 173.1145 - val_box_out_loss: 2092.1023 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 1.0114e-11 - val_loss: 1969.3871 - learning_rate: 0.0030
# Epoch 6/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 136.5619 - class_out_accuracy: 1.0000 - class_out_loss: 5.1271e-10 - loss: 136.1907
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 846ms/step - box_out_loss: 137.0789 - class_out_accuracy: 1.0000 - class_out_loss: 5.1331e-10 - loss: 136.6920 - val_box_out_loss: 2124.0571 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 2.8336e-15 - val_loss: 1994.1886 - learning_rate: 0.0030
# Epoch 7/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 191.0908 - class_out_accuracy: 1.0000 - class_out_loss: 6.8883e-10 - loss: 189.2308
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 848ms/step - box_out_loss: 190.6702 - class_out_accuracy: 1.0000 - class_out_loss: 8.6147e-10 - loss: 188.8243 - val_box_out_loss: 2004.6089 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 1.3073e-10 - val_loss: 1891.5406 - learning_rate: 0.0030
# Epoch 8/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 123.1506 - class_out_accuracy: 1.0000 - class_out_loss: 6.0975e-09 - loss: 122.8307
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 847ms/step - box_out_loss: 123.5782 - class_out_accuracy: 1.0000 - class_out_loss: 6.0492e-09 - loss: 123.2432 - val_box_out_loss: 2419.8726 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 8.1799e-17 - val_loss: 2302.0835 - learning_rate: 0.0030
# Epoch 9/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/steptep - box_out_loss: 136.1411 - class_out_accuracy: 1.0000 - class_out_loss: 4.9847e-08 - loss: 135.5670
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 856ms/step - box_out_loss: 136.4366 - class_out_accuracy: 1.0000 - class_out_loss: 5.1017e-08 - loss: 135.8515 - val_box_out_loss: 1947.7395 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 2.3765e-16 - val_loss: 1842.5077 - learning_rate: 0.0030
# Epoch 10/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 126.7894 - class_out_accuracy: 1.0000 - class_out_loss: 8.5766e-09 - loss: 126.2563
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 848ms/step - box_out_loss: 127.0587 - class_out_accuracy: 1.0000 - class_out_loss: 8.6379e-09 - loss: 126.5164 - val_box_out_loss: 1908.7274 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 1.2158e-11 - val_loss: 1791.0970 - learning_rate: 0.0030
# Epoch 11/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 115.1881 - class_out_accuracy: 1.0000 - class_out_loss: 1.0009e-05 - loss: 114.9192
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 865ms/step - box_out_loss: 115.5794 - class_out_accuracy: 1.0000 - class_out_loss: 1.0242e-05 - loss: 115.2963 - val_box_out_loss: 2306.1506 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 5.2503e-26 - val_loss: 2181.1118 - learning_rate: 0.0030
# tf.Tensor(0.002582124, shape=(), dtype=float32)
# Epoch 12/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 178.5620 - class_out_accuracy: 1.0000 - class_out_loss: 6.6208e-20 - loss: 175.7817
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 57s 906ms/step - box_out_loss: 177.5532 - class_out_accuracy: 1.0000 - class_out_loss: 6.5559e-20 - loss: 174.8024 - val_box_out_loss: 1904.7930 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 2.1944e-25 - val_loss: 1795.0970 - learning_rate: 0.0026
# tf.Tensor(0.0022224546, shape=(), dtype=float32)
# Epoch 13/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 76.0157 - class_out_accuracy: 1.0000 - class_out_loss: 2.9233e-22 - loss: 75.5923
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 56s 891ms/step - box_out_loss: 76.3009 - class_out_accuracy: 1.0000 - class_out_loss: 3.1410e-22 - loss: 75.8676 - val_box_out_loss: 1889.0271 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 3.6127e-24 - val_loss: 1777.3346 - learning_rate: 0.0022
# tf.Tensor(0.0019128845, shape=(), dtype=float32)
# Epoch 14/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 82.7478 - class_out_accuracy: 1.0000 - class_out_loss: 4.0043e-20 - loss: 81.8220
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 871ms/step - box_out_loss: 82.6873 - class_out_accuracy: 1.0000 - class_out_loss: 3.9945e-20 - loss: 81.7623 - val_box_out_loss: 1951.4001 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 1.2855e-24 - val_loss: 1839.3264 - learning_rate: 0.0019
# tf.Tensor(0.001646435, shape=(), dtype=float32)
# Epoch 15/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 44.6796 - class_out_accuracy: 1.0000 - class_out_loss: 1.1386e-21 - loss: 44.4661
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 863ms/step - box_out_loss: 44.9414 - class_out_accuracy: 1.0000 - class_out_loss: 1.3316e-21 - loss: 44.7166 - val_box_out_loss: 1861.3656 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 4.0110e-25 - val_loss: 1754.5547 - learning_rate: 0.0016
# tf.Tensor(0.0014170997, shape=(), dtype=float32)
# Epoch 16/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 38.6687 - class_out_accuracy: 1.0000 - class_out_loss: 1.6711e-21 - loss: 38.5761
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 870ms/step - box_out_loss: 38.8986 - class_out_accuracy: 1.0000 - class_out_loss: 1.6594e-21 - loss: 38.7951 - val_box_out_loss: 1822.0820 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 1.4120e-27 - val_loss: 1729.3293 - learning_rate: 0.0014
# tf.Tensor(0.001219709, shape=(), dtype=float32)
# Epoch 17/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 53.8543 - class_out_accuracy: 1.0000 - class_out_loss: 1.8518e-21 - loss: 52.9982
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 869ms/step - box_out_loss: 53.7625 - class_out_accuracy: 1.0000 - class_out_loss: 1.8392e-21 - loss: 52.9106 - val_box_out_loss: 1854.4873 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 2.2861e-25 - val_loss: 1746.8718 - learning_rate: 0.0012
# tf.Tensor(0.0010498133, shape=(), dtype=float32)
# Epoch 18/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 29.5904 - class_out_accuracy: 1.0000 - class_out_loss: 2.5982e-22 - loss: 29.4401
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 867ms/step - box_out_loss: 29.7921 - class_out_accuracy: 1.0000 - class_out_loss: 2.5972e-22 - loss: 29.6329 - val_box_out_loss: 1872.3938 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 4.4853e-27 - val_loss: 1773.5437 - learning_rate: 0.0010
# tf.Tensor(0.0009035827, shape=(), dtype=float32)
# Epoch 19/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 36.8939 - class_out_accuracy: 1.0000 - class_out_loss: 1.2566e-21 - loss: 36.4790
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 866ms/step - box_out_loss: 36.9458 - class_out_accuracy: 1.0000 - class_out_loss: 1.2478e-21 - loss: 36.5276 - val_box_out_loss: 1850.3879 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 4.3241e-26 - val_loss: 1742.1344 - learning_rate: 9.0358e-04
# tf.Tensor(0.0007777209, shape=(), dtype=float32)
# Epoch 20/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/steptep - box_out_loss: 24.7928 - class_out_accuracy: 1.0000 - class_out_loss: 2.0437e-22 - loss: 24.6323
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 867ms/step - box_out_loss: 24.9814 - class_out_accuracy: 1.0000 - class_out_loss: 2.0536e-22 - loss: 24.8133 - val_box_out_loss: 1841.9436 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 1.4123e-26 - val_loss: 1739.4615 - learning_rate: 7.7772e-04
# tf.Tensor(0.0006693906, shape=(), dtype=float32)
# Epoch 21/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 24.1207 - class_out_accuracy: 1.0000 - class_out_loss: 7.1844e-22 - loss: 24.0150
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 56s 884ms/step - box_out_loss: 24.3115 - class_out_accuracy: 1.0000 - class_out_loss: 7.1687e-22 - loss: 24.1978 - val_box_out_loss: 1818.6252 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 5.0330e-27 - val_loss: 1719.6039 - learning_rate: 6.6939e-04
# tf.Tensor(0.00057614985, shape=(), dtype=float32)
# Epoch 22/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 32.7875 - class_out_accuracy: 1.0000 - class_out_loss: 1.2442e-21 - loss: 32.3624
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 864ms/step - box_out_loss: 32.8069 - class_out_accuracy: 1.0000 - class_out_loss: 1.2349e-21 - loss: 32.3804 - val_box_out_loss: 1846.6525 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 8.6275e-26 - val_loss: 1738.0514 - learning_rate: 5.7615e-04
# tf.Tensor(0.0004958968, shape=(), dtype=float32)
# Epoch 23/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/steptep - box_out_loss: 39.1786 - class_out_accuracy: 1.0000 - class_out_loss: 8.7652e-23 - loss: 38.3346
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 864ms/step - box_out_loss: 39.0540 - class_out_accuracy: 1.0000 - class_out_loss: 8.9707e-23 - loss: 38.2156 - val_box_out_loss: 1836.8677 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 1.5649e-26 - val_loss: 1730.6625 - learning_rate: 4.9590e-04
# tf.Tensor(0.00042682234, shape=(), dtype=float32)
# Epoch 24/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 30.0922 - class_out_accuracy: 1.0000 - class_out_loss: 8.6521e-22 - loss: 29.5445
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 865ms/step - box_out_loss: 30.0824 - class_out_accuracy: 1.0000 - class_out_loss: 8.5992e-22 - loss: 29.5356 - val_box_out_loss: 1839.8429 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 2.6904e-26 - val_loss: 1732.5612 - learning_rate: 4.2682e-04
# tf.Tensor(0.00036736942, shape=(), dtype=float32)
# Epoch 25/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/steptep - box_out_loss: 15.4332 - class_out_accuracy: 1.0000 - class_out_loss: 1.2347e-22 - loss: 15.4172
# Class: y_true= [1]  | y_pred= 1
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 55s 872ms/step - box_out_loss: 15.6176 - class_out_accuracy: 1.0000 - class_out_loss: 1.2370e-22 - loss: 15.5940 - val_box_out_loss: 1826.8186 - val_class_out_accuracy: 1.0000 - val_class_out_loss: 1.3455e-26 - val_loss: 1722.2773 - learning_rate: 3.6737e-04

# %%
# Accuracy & Loss Visualization

#  Overall Loss
train_overall_loss = history.history['loss']
val_overall_loss = history.history['val_loss']

# Classification Accuracy
train_classification_acc = history.history['class_out_accuracy']
val_classification_acc = history.history['val_class_out_accuracy']

# Classification Loss
train_classification_loss = history.history['class_out_loss']
val_classification_loss = history.history['val_class_out_loss']

# Bounding Box Loss
train_bbox_loss = history.history['box_out_loss']
val_bbox_loss = history.history['val_box_out_loss']

epochs = range(1, len(history.history['loss'])+1)

f, ax = plt.subplots(nrows=2,ncols=2,figsize=(18,15))
    
ax[0,0].plot(epochs, train_overall_loss,  marker='o', label='Training')
ax[0,0].plot(epochs, val_overall_loss, marker='o', color = 'green', label='Validation')
ax[0,0].set_title('Overall Loss')
ax[0,0].set_xlabel('Epochs')
ax[0,0].set_ylabel('Loss')
ax[0,0].legend(loc='best')
ax[0,0].grid(True)

ax[0,1].plot(epochs, train_bbox_loss, marker='o', label='Training')
ax[0,1].plot(epochs, val_bbox_loss, marker='o', color = 'green', label='Validation')
ax[0,1].set_title('Bounding Box Loss')
ax[0,1].set_xlabel('Epochs')
ax[0,1].set_ylabel('Loss')
ax[0,1].legend(loc='best')
ax[0,1].grid(True)



ax[1,0].plot(epochs, train_classification_acc,  marker='o', label='Training')
ax[1,0].plot(epochs, val_classification_acc, marker='o', color = 'green', label='Validation')
ax[1,0].set_title('Classification Accuracy')
ax[1,0].set_xlabel('Epochs')
ax[1,0].set_ylabel('Accuracy')
ax[1,0].legend(loc='best')
ax[1,0].grid(True)

ax[1,1].plot(epochs, train_classification_loss, marker='o', label='Training')
ax[1,1].plot(epochs, val_classification_loss, marker='o', color = 'green', label='Validation')
ax[1,1].set_title('Classification Loss')
ax[1,1].set_xlabel('Epochs')
ax[1,1].set_ylabel('Loss')
ax[1,1].legend(loc='best')
ax[1,1].grid(True)

plt.show()
f.savefig('LossAndAccuracy.eps', format='eps')
plt.close()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
model.save("test1 ball detection.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
